# %%
import pandas
import numpy
from numpy import std, correlate, sqrt
from scipy.stats import pearsonr
import statsmodels.api as sm
from statsmodels.stats.mediation import Mediation
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %% [markdown]
# ### Preparing data

# %%
filepath = 'D:/DEA/Data/Original_data.txt'
data = pandas.read_csv(filepath,sep='\t')
data.rename(columns={'origi':'Id'},inplace=True)
print(data.shape,'from 2019_05_25_Results.xlxs')
print(data.Year.unique(),'Years')
print(data.Id.nunique(),'Number of firms')
filepath = 'D:/DEA/Data/Database_secondreviewJIBS.dta' #
data1 = pandas.read_stata(filepath)
data1.rename(columns={'id':'Id','year':'Year','country':'Country'},inplace=True)
data1 = data1[['Id','Year','Country']]
data1['Year'] = pandas.to_numeric(data1.Year.astype(str).str[0:4])
print(data1.shape,'to get country')
data = pandas.merge(left=data,right=data1,how='left',on=['Year','Id'])
print(data.Country.unique())
filepath = 'D:/DEA/Data/2019_05_25_Results_updated.txt'
data2 = pandas.read_csv(filepath,sep='\t')
print(data2.shape,'correction by Elio of market commonality')
data2.rename(columns={'origi':'Id'},inplace=True)
data2 = data2[['Id','Year','Market_commonality']]
data.drop('Market_commonality',axis=1,inplace = True)
data = pandas.merge(left=data,right=data2,how='inner',on=['Year','Id'])
print(data.Non_RD_alliances.sum(),'Total number of Non-RD alliances')
print(data.RD_alliances.sum(),'Total number of RD alliances')
# Out:
# (1232, 33) from 2019_05_25_Results.xlxs
# [1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004
#  2005 2006 2007 2008 2009 2010 2011 2012] Years
# 56 Number of firms
# (1539, 3) to get country
# [nan 'USA' 'Switzerland' 'Netherlands' 'Germany' 'South Africa' 'Japan'
#  'United Kingdom' 'France' 'Australia' 'Ireland' 'Spain' 'Denmark'
#  'Sweden']
# (1232, 34) correction by Elio of market commonality
# 4089.0 Total number of Non-RD alliances
# 7676.0 Total number of RD alliances

# %% [markdown]
# ### Creating variables

# %%
df = data.copy()
df.reset_index(inplace=True,drop=True)
df = df.sort_values(by=['Id','Year'], axis=0, ascending=True)
# ASPIRATIONS
df['SA']=df.groupby(['Year']).ROE.transform('sum')-df.ROE
df['n']=df.groupby(['Year']).ROE.transform('count')-1
df['SA']=df['SA']/df['n']
df['distance']=df['ROE']-df['SA']
df.loc[df.distance<0,'BSA']=df['distance']
df.loc[(df.distance>0)|(df.distance==0),'BSA']=0
df.loc[(df.distance>0)|(df.distance==0),'ASA']=df['distance']
df.loc[df.distance<0,'ASA']=0
df['BSA'] = df.groupby('Id')['BSA'].shift()
# DURATION
df['DURATION'] = 0
mylist = []
for i in range(df.Id.nunique()):
  mylist.append(df.loc[df.Id==i+1,['Id','Year','BSA','DURATION']].values.tolist())
m = [0]
for firm in range(df.Id.nunique()):
  for i in mylist[firm]: 
    if i[2]<0:
      m.append([i[0],i[1],m[-1][2]+1])
    else:
      m.append([i[0],i[1],i[3]])
del m[0]
print(len(m))
mydf = pandas.DataFrame(m,columns=['Id','Year','DURATION'])
df = df.drop('DURATION',axis=1)
df = pandas.merge(left=df,right=mydf,how='inner',on=['Year','Id'])
print(df.loc[(df.Id==38)|(df.Id==39),['Id','Year','BSA','DURATION']])
# ATTENTION
filepath = 'D:/DEA/Data/Results_def_01_for_Elio.txt'
data5 = pandas.read_csv(filepath,sep='\t')
data5 = data5.iloc[1:1008,[0,1,25,26,27]]
data5.columns = ['Year','Id','PRODUCT','GEOGRAPHY','GROWTH']
data5['Year'] = pandas.to_numeric(data5.Year.astype(str).str[0:4])
df = pandas.merge(left=df,right=data5,how='inner',on=['Year','Id'])
# R&D SEARCH
print(df.Non_RD_alliances.corr(df.RD_alliances),'correlation between RD alliances and non-RD alliances')
df['RD'] = df.RD_alliances
# SIZE
df['Size'] = numpy.log(df.Employees) 
df
# Out:
# 1232
#      Id  Year       BSA  DURATION
# 814  38  1991       NaN       0.0
# 815  38  1992  0.000000       0.0
# 816  38  1993  0.000000       0.0
# 817  38  1994  0.000000       0.0
# 818  38  1995  0.000000       0.0
# 819  38  1996 -0.014711       1.0
# 820  38  1997 -0.099922       2.0
# 821  38  1998  0.000000       0.0
# 822  38  1999 -0.213096       1.0
# 823  38  2000 -0.060731       2.0
# 824  38  2001 -0.127189       3.0
# 825  38  2002 -0.009038       4.0
# 826  38  2003  0.000000       0.0
# 827  38  2004  0.000000       0.0
# 828  38  2005 -0.046308       1.0
# 829  38  2006 -0.000654       2.0
# 830  38  2007 -0.000157       3.0
# 831  38  2008 -0.646780       4.0
# 832  38  2009 -0.264653       5.0
# 833  38  2010 -0.167467       6.0
# 834  38  2011 -0.091477       7.0
# 835  38  2012 -0.106878       8.0
# 836  39  1991       NaN       0.0
# 837  39  1992       NaN       0.0
# 838  39  1993       NaN       0.0
# 839  39  1994       NaN       0.0
# 840  39  1995       NaN       0.0
# 841  39  1996       NaN       0.0
# 842  39  1997 -0.113176       1.0
# 843  39  1998  0.000000       0.0
# 844  39  1999 -0.124423       1.0
# 845  39  2000  0.000000       0.0
# 846  39  2001  0.000000       0.0
# 847  39  2002 -0.029415       1.0
# 848  39  2003  0.000000       0.0
# 849  39  2004  0.000000       0.0
# 850  39  2005  0.000000       0.0
# 851  39  2006 -0.049577       1.0
# 852  39  2007  0.000000       0.0
# 853  39  2008 -0.058240       1.0
# 854  39  2009 -0.029959       2.0
# 855  39  2010 -0.093867       3.0
# 856  39  2011 -0.045455       4.0
# 857  39  2012 -0.122244       5.0
# 0.7259338699988971 correlation between RD alliances and non-RD alliances
#       Id  Year    Age  Employees Total_assets  Net_sales  Human_resources_1  \
# 0      1  1996   94.0    74289.0    13364.000  14236.000              0.192
# 1      1  1997   95.0    75639.0    13238.000  15070.000              0.199
# 2      1  1998   96.0    73564.0    14153.000  15021.000              0.204
# 3      1  1999   97.0    70549.0    13896.000  15659.000              0.222
# 4      1  2000   98.0    75000.0    14522.000  16724.000              0.223
# ...   ..   ...    ...        ...          ...        ...                ...
# 1002  56  2008  148.0    47426.0    44031.724  22833.908              0.481
# 1003  56  2009    NaN        NaN          NaN        NaN                NaN
# 1004  56  2010    NaN        NaN          NaN        NaN                NaN
# 1005  56  2011    NaN        NaN          NaN        NaN                NaN
# 1006  56  2012    NaN        NaN          NaN        NaN                NaN
#
#       Human_resources_2  Physical_resources_1  Physical_resources_2  ...   n  \
# 0                 5.218              4844.000                 0.340  ...  51
# 1                 5.019              5034.000                 0.334  ...  51
# 2                 4.897              5566.000                 0.371  ...  52
# 3                 4.505              5656.000                 0.361  ...  52
# 4                 4.485              5823.000                 0.348  ...  53
# ...                 ...                   ...                   ...  ...  ..
# 1002              2.077             11198.211                 0.490  ...  49
# 1003                NaN                   NaN                   NaN  ...  45
# 1004                NaN                   NaN                   NaN  ...  44
# 1005                NaN                   NaN                   NaN  ...  41
# 1006                NaN                   NaN                   NaN  ...  41
#
#       distance       BSA       ASA  DURATION  PRODUCT  GEOGRAPHY    GROWTH  \
# 0     0.049961 -0.039244  0.049961       1.0      0.0   0.784127  0.215873
# 1     0.232902  0.000000  0.232902       0.0      0.0   0.774649  0.225351
# 2    -0.122385  0.000000  0.000000       0.0      0.0   0.750883  0.249117
# 3     0.094192 -0.122385  0.094192       1.0      0.0   0.793790  0.206210
# 4     0.117340  0.000000  0.117340       0.0      0.0   0.788899  0.211101
# ...        ...       ...       ...       ...      ...        ...       ...
# 1002  0.038408 -0.048040  0.038408       1.0      NaN        NaN       NaN
# 1003       NaN  0.000000       NaN       0.0      NaN        NaN       NaN
# 1004       NaN       NaN       NaN       0.0      NaN        NaN       NaN
# 1005       NaN       NaN       NaN       0.0      NaN        NaN       NaN
# 1006       NaN       NaN       NaN       0.0      NaN        NaN       NaN
#
#        RD       Size
# 0     0.0  11.215718
# 1     0.0  11.233727
# 2     2.0  11.205911
# 3     0.0  11.164063
# 4     0.0  11.225243
# ...   ...        ...
# 1002  4.0  10.766926
# 1003  4.0        NaN
# 1004  NaN        NaN
# 1005  NaN        NaN
# 1006  NaN        NaN
#
# [1007 rows x 45 columns]

# %% [markdown]
# ### Correlation

# %%
mydata = df[['RD','BSA','DURATION','PRODUCT','GROWTH','GEOGRAPHY','ASA','Absorbed_slack','Unabsorbed_slack','Absorptive_capacity','Market_commonality','Size','Year']]
print(len(mydata),'Number of observations')
ds_mean = mydata.agg(['mean','std']).T
corr = mydata.corr()
corr = pandas.concat([ds_mean,corr], axis = 1)
corr = corr.applymap('{:.2f}'.format)
corr['statistics'] = ' '
corr.set_index('statistics',append=True,inplace=True)
print(corr)

def pearsonr_pval(x,y):
  return pearsonr(x,y)[1].round(3)
pval = mydata.corr(method=pearsonr_pval)
pval = pval.applymap('{:.3f}'.format)
pval = pval.applymap(lambda x: '(' + x + ')')
pval['statistics'] = 'p-value'
pval.set_index('statistics',append=True,inplace=True)

corr = pandas.concat([corr,pval],axis=0).sort_index(kind='merge').reindex(['R&D','BSA','DURATION','PRODUCT','GROWTH','GEOGRAPHY','ASA','Absorbed_slack','Unabsorbed_slack','Absorptive_capacity','Market_commonality','Size','Year'],axis=0,level=0)
filepath = 'D:/DEA/DEA-2/Correlation.txt'
corr.to_csv(filepath,sep = '\t',header=False,index=False)
corr
# Out:
# 1007 Number of observations
#                                    mean    std     RD    BSA DURATION PRODUCT  \
#                     statistics
# RD                                 8.04   8.55   1.00   0.15    -0.22    0.02
# BSA                               -0.10   0.22   0.15   1.00    -0.23   -0.07
# DURATION                           2.96   4.61  -0.22  -0.23     1.00    0.15
# PRODUCT                            0.64   0.41   0.02  -0.07     0.15    1.00
# GROWTH                             0.15   0.16   0.06   0.08    -0.03   -0.62
# GEOGRAPHY                          0.21   0.33  -0.06   0.05    -0.17   -0.92
# ASA                                0.10   0.34   0.06  -0.15    -0.14   -0.10
# Absorbed_slack                     1.97  37.88  -0.04   0.01    -0.02    0.23
# Unabsorbed_slack                   1.39   1.99  -0.18  -0.22     0.08    0.18
# Absorptive_capacity                0.23   0.72  -0.07  -0.42     0.06    0.18
# Market_commonality                 0.41   0.14   0.01  -0.09     0.05   -0.12
# Size                               9.37   1.76   0.41   0.34    -0.17   -0.28
# Year                            2003.51   5.19  -0.14   0.03     0.17    0.01
#
#                                GROWTH GEOGRAPHY    ASA Absorbed_slack  \
#                     statistics
# RD                               0.06     -0.06   0.06          -0.04
# BSA                              0.08      0.05  -0.15           0.01
# DURATION                        -0.03     -0.17  -0.14          -0.02
# PRODUCT                         -0.62     -0.92  -0.10           0.23
# GROWTH                           1.00      0.28   0.11          -0.19
# GEOGRAPHY                        0.28      1.00   0.07          -0.18
# ASA                              0.11      0.07   1.00          -0.01
# Absorbed_slack                  -0.19     -0.18  -0.01           1.00
# Unabsorbed_slack                -0.09     -0.17   0.10           0.01
# Absorptive_capacity             -0.12     -0.17   0.13           0.00
# Market_commonality               0.12      0.08  -0.02          -0.02
# Size                             0.18      0.26   0.04          -0.10
# Year                            -0.06      0.02  -0.03           0.07
#
#                                Unabsorbed_slack Absorptive_capacity  \
#                     statistics
# RD                                        -0.18               -0.07
# BSA                                       -0.22               -0.42
# DURATION                                   0.08                0.06
# PRODUCT                                    0.18                0.18
# GROWTH                                    -0.09               -0.12
# GEOGRAPHY                                 -0.17               -0.17
# ASA                                        0.10                0.13
# Absorbed_slack                             0.01                0.00
# Unabsorbed_slack                           1.00                0.34
# Absorptive_capacity                        0.34                1.00
# Market_commonality                         0.06                0.09
# Size                                      -0.37               -0.29
# Year                                      -0.09               -0.11
#
#                                Market_commonality   Size   Year
#                     statistics
# RD                                           0.01   0.41  -0.14
# BSA                                         -0.09   0.34   0.03
# DURATION                                     0.05  -0.17   0.17
# PRODUCT                                     -0.12  -0.28   0.01
# GROWTH                                       0.12   0.18  -0.06
# GEOGRAPHY                                    0.08   0.26   0.02
# ASA                                         -0.02   0.04  -0.03
# Absorbed_slack                              -0.02  -0.10   0.07
# Unabsorbed_slack                             0.06  -0.37  -0.09
# Absorptive_capacity                          0.09  -0.29  -0.11
# Market_commonality                           1.00   0.04  -0.24
# Size                                         0.04   1.00   0.25
# Year                                        -0.24   0.25   1.00
#                                    mean    std       RD      BSA DURATION  \
#                     statistics
# BSA                               -0.10   0.22     0.15     1.00    -0.23
#                     p-value         NaN    NaN  (0.000)  (1.000)  (0.000)
# DURATION                           2.96   4.61    -0.22    -0.23     1.00
#                     p-value         NaN    NaN  (0.000)  (0.000)  (1.000)
# PRODUCT                            0.64   0.41     0.02    -0.07     0.15
#                     p-value         NaN    NaN  (0.649)  (0.087)  (0.001)
# GROWTH                             0.15   0.16     0.06     0.08    -0.03
#                     p-value         NaN    NaN  (0.175)  (0.076)  (0.434)
# GEOGRAPHY                          0.21   0.33    -0.06     0.05    -0.17
#                     p-value         NaN    NaN  (0.220)  (0.215)  (0.000)
# ASA                                0.10   0.34     0.06    -0.15    -0.14
#                     p-value         NaN    NaN  (0.102)  (0.000)  (0.000)
# Absorbed_slack                     1.97  37.88    -0.04     0.01    -0.02
#                     p-value         NaN    NaN  (0.322)  (0.797)  (0.571)
# Unabsorbed_slack                   1.39   1.99    -0.18    -0.22     0.08
#                     p-value         NaN    NaN  (0.000)  (0.000)  (0.027)
# Absorptive_capacity                0.23   0.72    -0.07    -0.42     0.06
#                     p-value         NaN    NaN  (0.046)  (0.000)  (0.053)
# Market_commonality                 0.41   0.14     0.01    -0.09     0.05
#                     p-value         NaN    NaN  (0.771)  (0.009)  (0.150)
# Size                               9.37   1.76     0.41     0.34    -0.17
#                     p-value         NaN    NaN  (0.000)  (0.000)  (0.000)
# Year                            2003.51   5.19    -0.14     0.03     0.17
#                     p-value         NaN    NaN  (0.000)  (0.342)  (0.000)
#
#                                 PRODUCT   GROWTH GEOGRAPHY      ASA  \
#                     statistics
# BSA                               -0.07     0.08      0.05    -0.15
#                     p-value     (0.087)  (0.076)   (0.215)  (0.000)
# DURATION                           0.15    -0.03     -0.17    -0.14
#                     p-value     (0.001)  (0.434)   (0.000)  (0.000)
# PRODUCT                            1.00    -0.62     -0.92    -0.10
#                     p-value     (1.000)  (0.000)   (0.000)  (0.020)
# GROWTH                            -0.62     1.00      0.28     0.11
#                     p-value     (0.000)  (1.000)   (0.000)  (0.010)
# GEOGRAPHY                         -0.92     0.28      1.00     0.07
#                     p-value     (0.000)  (0.000)   (1.000)  (0.110)
# ASA                               -0.10     0.11      0.07     1.00
#                     p-value     (0.020)  (0.010)   (0.110)  (1.000)
# Absorbed_slack                     0.23    -0.19     -0.18    -0.01
#                     p-value     (0.000)  (0.000)   (0.000)  (0.722)
# Unabsorbed_slack                   0.18    -0.09     -0.17     0.10
#                     p-value     (0.000)  (0.070)   (0.000)  (0.007)
# Absorptive_capacity                0.18    -0.12     -0.17     0.13
#                     p-value     (0.000)  (0.004)   (0.000)  (0.000)
# Market_commonality                -0.12     0.12      0.08    -0.02
#                     p-value     (0.007)  (0.005)   (0.051)  (0.558)
# Size                              -0.28     0.18      0.26     0.04
#                     p-value     (0.000)  (0.000)   (0.000)  (0.294)
# Year                               0.01    -0.06      0.02    -0.03
#                     p-value     (0.883)  (0.175)   (0.632)  (0.421)
#
#                                Absorbed_slack Unabsorbed_slack  \
#                     statistics
# BSA                                      0.01            -0.22
#                     p-value           (0.797)          (0.000)
# DURATION                                -0.02             0.08
#                     p-value           (0.571)          (0.027)
# PRODUCT                                  0.23             0.18
#                     p-value           (0.000)          (0.000)
# GROWTH                                  -0.19            -0.09
#                     p-value           (0.000)          (0.070)
# GEOGRAPHY                               -0.18            -0.17
#                     p-value           (0.000)          (0.000)
# ASA                                     -0.01             0.10
#                     p-value           (0.722)          (0.007)
# Absorbed_slack                           1.00             0.01
#                     p-value           (1.000)          (0.771)
# Unabsorbed_slack                         0.01             1.00
#                     p-value           (0.771)          (1.000)
# Absorptive_capacity                      0.00             0.34
#                     p-value           (0.952)          (0.000)
# Market_commonality                      -0.02             0.06
#                     p-value           (0.662)          (0.092)
# Size                                    -0.10            -0.37
#                     p-value           (0.014)          (0.000)
# Year                                     0.07            -0.09
#                     p-value           (0.069)          (0.015)
#
#                                Absorptive_capacity Market_commonality  \
#                     statistics
# BSA                                          -0.42              -0.09
#                     p-value                (0.000)            (0.009)
# DURATION                                      0.06               0.05
#                     p-value                (0.053)            (0.150)
# PRODUCT                                       0.18              -0.12
#                     p-value                (0.000)            (0.007)
# GROWTH                                       -0.12               0.12
#                     p-value                (0.004)            (0.005)
# GEOGRAPHY                                    -0.17               0.08
#                     p-value                (0.000)            (0.051)
# ASA                                           0.13              -0.02
#                     p-value                (0.000)            (0.558)
# Absorbed_slack                                0.00              -0.02
#                     p-value                (0.952)            (0.662)
# Unabsorbed_slack                              0.34               0.06
#                     p-value                (0.000)            (0.092)
# Absorptive_capacity                           1.00               0.09
#                     p-value                (1.000)            (0.011)
# Market_commonality                            0.09               1.00
#                     p-value                (0.011)            (1.000)
# Size                                         -0.29               0.04
#                     p-value                (0.000)            (0.306)
# Year                                         -0.11              -0.24
#                     p-value                (0.001)            (0.000)
#
#                                    Size     Year
#                     statistics
# BSA                                0.34     0.03
#                     p-value     (0.000)  (0.342)
# DURATION                          -0.17     0.17
#                     p-value     (0.000)  (0.000)
# PRODUCT                           -0.28     0.01
#                     p-value     (0.000)  (0.883)
# GROWTH                             0.18    -0.06
#                     p-value     (0.000)  (0.175)
# GEOGRAPHY                          0.26     0.02
#                     p-value     (0.000)  (0.632)
# ASA                                0.04    -0.03
#                     p-value     (0.294)  (0.421)
# Absorbed_slack                    -0.10     0.07
#                     p-value     (0.014)  (0.069)
# Unabsorbed_slack                  -0.37    -0.09
#                     p-value     (0.000)  (0.015)
# Absorptive_capacity               -0.29    -0.11
#                     p-value     (0.000)  (0.001)
# Market_commonality                 0.04    -0.24
#                     p-value     (0.306)  (0.000)
# Size                               1.00     0.25
#                     p-value     (1.000)  (0.000)
# Year                               0.25     1.00
#                     p-value     (0.000)  (1.000)

# %% [markdown]
# ## Attention to growth

# %%
mydata = df[['Id','RD','PRODUCT','GROWTH','GEOGRAPHY','BSA','DURATION','ASA','Absorbed_slack','Unabsorbed_slack','Absorptive_capacity','Market_commonality','Size','Year']]
mydata = mydata.dropna()
mydata = mydata.sort_values(by=['Id','Year'], axis=0, ascending=True)
mediator_model = sm.OLS.from_formula('GROWTH~BSA+DURATION+C(Id)', data=mydata)
outcome_model = sm.OLS.from_formula('RD~BSA+DURATION+GROWTH+ASA+Absorbed_slack+Unabsorbed_slack+Absorptive_capacity+Market_commonality+Size+C(Id)',data=mydata)        
mediator = mediator_model.fit(cov_type='hac-panel',cov_kwds={'maxlags':1,'groups':mydata['Id']})
outcome = outcome_model.fit(cov_type='hac-panel',cov_kwds={'maxlags':1,'groups':mydata['Id']})
print(mediator.summary())
print(outcome.summary())
BSA_Mediation = Mediation(outcome_model,mediator_model,'BSA','GROWTH').fit(n_rep=250)
print(BSA_Mediation.summary())
Duration_Mediation = Mediation(outcome_model,mediator_model,'DURATION','GROWTH').fit(n_rep=250)
print(Duration_Mediation.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 GROWTH   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.910
# Method:                 Least Squares   F-statistic:                     185.5
# Date:                Fri, 05 Mar 2021   Prob (F-statistic):           2.62e-36
# Time:                        13:31:22   Log-Likelihood:                 614.30
# No. Observations:                 374   AIC:                            -1141.
# Df Residuals:                     330   BIC:                            -967.9
# Df Model:                          43
# Covariance Type:            hac-panel
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.1971      0.009     22.900      0.000       0.180       0.214
# C(Id)[T.2]      0.3410      0.021     16.176      0.000       0.300       0.382
# C(Id)[T.3]      0.2258      0.059      3.828      0.000       0.110       0.341
# C(Id)[T.4]     -0.1033      0.012     -8.590      0.000      -0.127      -0.080
# C(Id)[T.6]     -0.1450      0.010    -14.124      0.000      -0.165      -0.125
# C(Id)[T.7]     -0.0819      0.019     -4.355      0.000      -0.119      -0.045
# C(Id)[T.9]     -0.1437      0.009    -15.556      0.000      -0.162      -0.126
# C(Id)[T.10]    -0.0091      0.015     -0.595      0.552      -0.039       0.021
# C(Id)[T.11]    -0.1707      0.009    -19.490      0.000      -0.188      -0.154
# C(Id)[T.12]     0.2077      0.030      7.001      0.000       0.150       0.266
# C(Id)[T.14]    -0.0785      0.012     -6.575      0.000      -0.102      -0.055
# C(Id)[T.15]    -0.1965      0.009    -22.812      0.000      -0.213      -0.180
# C(Id)[T.16]     0.0361      0.022      1.661      0.097      -0.006       0.079
# C(Id)[T.17]    -0.1177      0.011    -10.592      0.000      -0.140      -0.096
# C(Id)[T.18]    -0.1325      0.011    -12.418      0.000      -0.153      -0.112
# C(Id)[T.23]    -0.0477      0.019     -2.482      0.013      -0.085      -0.010
# C(Id)[T.24]    -0.1080      0.012     -8.752      0.000      -0.132      -0.084
# C(Id)[T.25]    -0.1427      0.009    -15.585      0.000      -0.161      -0.125
# C(Id)[T.26]    -0.1415      0.009    -15.064      0.000      -0.160      -0.123
# C(Id)[T.28]    -0.0772      0.012     -6.247      0.000      -0.101      -0.053
# C(Id)[T.29]    -0.0944      0.013     -7.502      0.000      -0.119      -0.070
# C(Id)[T.30]    -0.0778      0.013     -5.934      0.000      -0.103      -0.052
# C(Id)[T.31]     0.2496      0.047      5.273      0.000       0.157       0.342
# C(Id)[T.32]    -0.1839      0.010    -18.643      0.000      -0.203      -0.165
# C(Id)[T.33]     0.3725      0.019     19.966      0.000       0.336       0.409
# C(Id)[T.36]     0.1767      0.047      3.769      0.000       0.085       0.269
# C(Id)[T.37]    -0.0749      0.025     -2.960      0.003      -0.124      -0.025
# C(Id)[T.38]     0.1050      0.072      1.453      0.146      -0.037       0.247
# C(Id)[T.39]    -0.1947      0.009    -22.495      0.000      -0.212      -0.178
# C(Id)[T.40]    -0.1725      0.009    -19.410      0.000      -0.190      -0.155
# C(Id)[T.42]    -0.1198      0.012     -9.724      0.000      -0.144      -0.096
# C(Id)[T.43]    -0.0622      0.022     -2.787      0.005      -0.106      -0.018
# C(Id)[T.44]     0.2270      0.026      8.652      0.000       0.176       0.278
# C(Id)[T.45]    -0.1266      0.010    -13.107      0.000      -0.145      -0.108
# C(Id)[T.46]    -0.1847      0.009    -20.346      0.000      -0.202      -0.167
# C(Id)[T.48]    -0.0167      0.014     -1.233      0.218      -0.043       0.010
# C(Id)[T.49]    -0.1483      0.019     -7.863      0.000      -0.185      -0.111
# C(Id)[T.50]    -0.1864      0.009    -19.904      0.000      -0.205      -0.168
# C(Id)[T.51]     0.0305      0.019      1.593      0.111      -0.007       0.068
# C(Id)[T.53]     0.0634      0.015      4.172      0.000       0.034       0.093
# C(Id)[T.54]    -0.1794      0.010    -18.683      0.000      -0.198      -0.161
# C(Id)[T.56]    -0.0447      0.011     -4.143      0.000      -0.066      -0.024
# BSA             0.0444      0.016      2.798      0.005       0.013       0.076
# DURATION       -0.0025      0.001     -2.487      0.013      -0.004      -0.001
# ==============================================================================
# Omnibus:                      157.310   Durbin-Watson:                   2.315
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1087.314
# Skew:                           1.619   Prob(JB):                    7.81e-237
# Kurtosis:                      10.700   Cond. No.                         209.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (HAC-Panel)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     RD   R-squared:                       0.756
# Model:                            OLS   Adj. R-squared:                  0.718
# Method:                 Least Squares   F-statistic:                     20.82
# Date:                Fri, 05 Mar 2021   Prob (F-statistic):           7.76e-18
# Time:                        13:31:22   Log-Likelihood:                -1102.7
# No. Observations:                 374   AIC:                             2307.
# Df Residuals:                     323   BIC:                             2507.
# Df Model:                          50
# Covariance Type:            hac-panel
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              26.8908     12.935      2.079      0.038       1.539      52.243
# C(Id)[T.2]              6.7705      1.932      3.505      0.000       2.984      10.557
# C(Id)[T.3]             -2.1222      4.136     -0.513      0.608     -10.228       5.984
# C(Id)[T.4]              1.1001      0.958      1.149      0.251      -0.777       2.977
# C(Id)[T.6]             -1.9401      2.717     -0.714      0.475      -7.266       3.386
# C(Id)[T.7]              6.4614      2.417      2.673      0.008       1.724      11.199
# C(Id)[T.9]             13.9800      1.332     10.495      0.000      11.369      16.591
# C(Id)[T.10]            -7.0156      3.869     -1.813      0.070     -14.598       0.567
# C(Id)[T.11]             4.1121      1.342      3.065      0.002       1.483       6.742
# C(Id)[T.12]            13.8614      2.713      5.109      0.000       8.543      19.179
# C(Id)[T.14]            -6.5276      4.181     -1.561      0.118     -14.722       1.667
# C(Id)[T.15]            16.9172      2.779      6.087      0.000      11.470      22.365
# C(Id)[T.16]            -2.8046      3.575     -0.784      0.433      -9.812       4.203
# C(Id)[T.17]            -2.1112      3.776     -0.559      0.576      -9.513       5.290
# C(Id)[T.18]             0.9837      3.477      0.283      0.777      -5.831       7.798
# C(Id)[T.23]             2.5223      2.974      0.848      0.396      -3.307       8.351
# C(Id)[T.24]            -7.6327      4.318     -1.768      0.077     -16.095       0.830
# C(Id)[T.25]             8.9695      2.005      4.474      0.000       5.040      12.899
# C(Id)[T.26]            -0.4014      2.742     -0.146      0.884      -5.776       4.973
# C(Id)[T.28]             3.5557      2.775      1.281      0.200      -1.883       8.994
# C(Id)[T.29]             3.0913      3.183      0.971      0.331      -3.147       9.329
# C(Id)[T.30]            -2.7012      3.599     -0.751      0.453      -9.755       4.353
# C(Id)[T.31]            18.8312      3.300      5.707      0.000      12.364      25.299
# C(Id)[T.32]            -3.0601      3.227     -0.948      0.343      -9.384       3.264
# C(Id)[T.33]            15.8451      2.459      6.443      0.000      11.025      20.665
# C(Id)[T.36]            -2.5073      4.525     -0.554      0.579     -11.375       6.361
# C(Id)[T.37]            16.5330      4.013      4.120      0.000       8.668      24.398
# C(Id)[T.38]            -4.0061      3.016     -1.328      0.184      -9.917       1.905
# C(Id)[T.39]            21.0384      2.550      8.250      0.000      16.040      26.036
# C(Id)[T.40]            -0.1195      1.782     -0.067      0.947      -3.613       3.374
# C(Id)[T.42]            30.5101      3.752      8.132      0.000      23.157      37.863
# C(Id)[T.43]            10.8233      1.378      7.852      0.000       8.122      13.525
# C(Id)[T.44]            -1.2122      1.623     -0.747      0.455      -4.392       1.968
# C(Id)[T.45]            25.1261      2.996      8.387      0.000      19.254      30.998
# C(Id)[T.46]            15.5055      2.082      7.446      0.000      11.424      19.587
# C(Id)[T.48]            -6.7469      3.646     -1.850      0.064     -13.894       0.400
# C(Id)[T.49]             1.3005      3.566      0.365      0.715      -5.689       8.290
# C(Id)[T.50]            -3.0252      4.649     -0.651      0.515     -12.137       6.087
# C(Id)[T.51]             1.7967      1.766      1.018      0.309      -1.664       5.257
# C(Id)[T.53]             5.7646      1.733      3.326      0.001       2.367       9.162
# C(Id)[T.54]            -1.9992      2.833     -0.706      0.480      -7.551       3.553
# C(Id)[T.56]             6.9175      1.294      5.344      0.000       4.380       9.455
# BSA                     3.9115      1.968      1.988      0.047       0.055       7.768
# DURATION               -0.3012      0.129     -2.335      0.020      -0.554      -0.048
# GROWTH                 11.8047      4.640      2.544      0.011       2.710      20.899
# ASA                     8.3651      3.834      2.182      0.029       0.851      15.879
# Absorbed_slack          5.5124      2.435      2.264      0.024       0.740      10.285
# Unabsorbed_slack       -0.6277      0.330     -1.903      0.057      -1.274       0.019
# Absorptive_capacity    -2.6577      1.242     -2.139      0.032      -5.093      -0.223
# Market_commonality      2.5475      2.713      0.939      0.348      -2.769       7.864
# Size                   -2.7597      1.161     -2.377      0.017      -5.036      -0.484
# ==============================================================================
# Omnibus:                       57.017   Durbin-Watson:                   1.201
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              172.416
# Skew:                           0.682   Prob(JB):                     3.63e-38
# Kurtosis:                       6.033   Cond. No.                         713.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (HAC-Panel)
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)            0.545474        0.004751        1.251653    0.048
# ACME (treated)            0.545474        0.004751        1.251653    0.048
# ADE (control)             3.897366       -0.025163        8.261306    0.056
# ADE (treated)             3.897366       -0.025163        8.261306    0.056
# Total effect              4.442839        0.368654        8.585126    0.032
# Prop. mediated (control)  0.116328       -0.002295        0.568279    0.064
# Prop. mediated (treated)  0.116328       -0.002295        0.568279    0.064
# ACME (average)            0.545474        0.004751        1.251653    0.048
# ADE (average)             3.897366       -0.025163        8.261306    0.056
# Prop. mediated (average)  0.116328       -0.002295        0.568279    0.064
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.026863       -0.137831        0.067394    0.560
# ACME (treated)           -0.026863       -0.137831        0.067394    0.560
# ADE (control)            -0.297757       -0.566552       -0.052935    0.024
# ADE (treated)            -0.297757       -0.566552       -0.052935    0.024
# Total effect             -0.324620       -0.609558       -0.067119    0.016
# Prop. mediated (control)  0.074107       -0.304799        0.508922    0.560
# Prop. mediated (treated)  0.074107       -0.304799        0.508922    0.560
# ACME (average)           -0.026863       -0.137831        0.067394    0.560
# ADE (average)            -0.297757       -0.566552       -0.052935    0.024
# Prop. mediated (average)  0.074107       -0.304799        0.508922    0.560

# %% [markdown]
# ## Attention to growth - Quadratic Aspirations

# %%
mydata = df[['Id','RD','PRODUCT','GROWTH','GEOGRAPHY','BSA','DURATION','ASA','Absorbed_slack','Unabsorbed_slack','Absorptive_capacity','Market_commonality','Size','Year']]
mydata = mydata.dropna()
mydata = (mydata - mydata.mean()) / mydata.std() 
mydata['BSA2'] = mydata['BSA']*mydata['BSA']
mydata = mydata.sort_values(by=['Id','Year'], axis=0, ascending=True)
mediator_model = sm.OLS.from_formula('GROWTH~BSA+BSA2+DURATION+C(Id)', data=mydata)
outcome_model = sm.OLS.from_formula('RD~BSA+BSA2+DURATION+GROWTH+ASA+Absorbed_slack+Unabsorbed_slack+Absorptive_capacity+Market_commonality+Size+C(Id)',data=mydata)        
mediator = mediator_model.fit(cov_type='hac-panel',cov_kwds={'maxlags':1,'groups':mydata['Id']})
outcome = outcome_model.fit(cov_type='hac-panel',cov_kwds={'maxlags':1,'groups':mydata['Id']})
print(mediator.summary())
print(outcome.summary())
BSA_Mediation = Mediation(outcome_model,mediator_model,'BSA','GROWTH').fit(n_rep=250)
print(BSA_Mediation.summary())
Duration_Mediation = Mediation(outcome_model,mediator_model,'DURATION','GROWTH').fit(n_rep=250)
print(Duration_Mediation.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 GROWTH   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.910
# Method:                 Least Squares   F-statistic:                     164.4
# Date:                Fri, 05 Mar 2021   Prob (F-statistic):           2.67e-35
# Time:                        13:32:15   Log-Likelihood:                -57.094
# No. Observations:                 374   AIC:                             204.2
# Df Residuals:                     329   BIC:                             380.8
# Df Model:                          44
# Covariance Type:            hac-panel
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         0.1872      0.055      3.375      0.001       0.079       0.296
# C(Id)[T.-1.438898846110549]       2.0542      0.127     16.129      0.000       1.805       2.304
# C(Id)[T.-1.3800462467617578]      1.3573      0.354      3.834      0.000       0.663       2.051
# C(Id)[T.-1.3211936474129669]     -0.6222      0.072     -8.614      0.000      -0.764      -0.481
# C(Id)[T.-1.2034884487153847]     -0.8657      0.064    -13.500      0.000      -0.991      -0.740
# C(Id)[T.-1.1446358493665936]     -0.4917      0.114     -4.302      0.000      -0.716      -0.268
# C(Id)[T.-1.0269306506690117]     -0.8657      0.056    -15.501      0.000      -0.975      -0.756
# C(Id)[T.-0.9680780513202205]     -0.0529      0.094     -0.566      0.571      -0.236       0.130
# C(Id)[T.-0.9092254519714295]     -1.0282      0.053    -19.219      0.000      -1.133      -0.923
# C(Id)[T.-0.8503728526226385]      1.2385      0.182      6.821      0.000       0.883       1.594
# C(Id)[T.-0.7326676539250564]     -0.4695      0.074     -6.343      0.000      -0.615      -0.324
# C(Id)[T.-0.6738150545762653]     -1.1847      0.053    -22.541      0.000      -1.288      -1.082
# C(Id)[T.-0.6149624552274743]      0.2193      0.133      1.651      0.099      -0.041       0.480
# C(Id)[T.-0.5561098558786832]     -0.6967      0.071     -9.854      0.000      -0.835      -0.558
# C(Id)[T.-0.4972572565298922]     -0.7944      0.065    -12.297      0.000      -0.921      -0.668
# C(Id)[T.-0.20299425978593702]    -0.3021      0.120     -2.515      0.012      -0.538      -0.067
# C(Id)[T.-0.14414166043714596]    -0.7019      0.065    -10.722      0.000      -0.830      -0.574
# C(Id)[T.-0.08528906108835493]    -0.8571      0.057    -15.170      0.000      -0.968      -0.746
# C(Id)[T.-0.02643646173956389]    -0.8528      0.057    -14.870      0.000      -0.965      -0.740
# C(Id)[T.0.0912687369580182]      -0.4592      0.075     -6.117      0.000      -0.606      -0.312
# C(Id)[T.0.15012133630680924]     -0.5659      0.076     -7.453      0.000      -0.715      -0.417
# C(Id)[T.0.20897393565560027]     -0.4613      0.082     -5.647      0.000      -0.621      -0.301
# C(Id)[T.0.2678265350043913]       1.5028      0.286      5.259      0.000       0.943       2.063
# C(Id)[T.0.32667913435318235]     -1.1019      0.062    -17.866      0.000      -1.223      -0.981
# C(Id)[T.0.3855317337019734]       2.2451      0.112     19.999      0.000       2.025       2.465
# C(Id)[T.0.5620895317483465]       1.0612      0.284      3.736      0.000       0.505       1.618
# C(Id)[T.0.6209421310971376]      -0.4464      0.153     -2.919      0.004      -0.746      -0.147
# C(Id)[T.0.6797947304459286]       0.6446      0.436      1.478      0.140      -0.210       1.500
# C(Id)[T.0.7386473297947196]      -1.1707      0.053    -22.066      0.000      -1.275      -1.067
# C(Id)[T.0.7974999291435106]      -1.0398      0.054    -19.183      0.000      -1.146      -0.934
# C(Id)[T.0.9152051278410928]      -0.7190      0.075     -9.593      0.000      -0.866      -0.572
# C(Id)[T.0.9740577271898838]      -0.3666      0.139     -2.644      0.008      -0.638      -0.095
# C(Id)[T.1.0329103265386748]       1.3685      0.158      8.679      0.000       1.059       1.678
# C(Id)[T.1.091762925887466]       -0.7596      0.060    -12.756      0.000      -0.876      -0.643
# C(Id)[T.1.1506155252362569]      -1.0969      0.062    -17.824      0.000      -1.217      -0.976
# C(Id)[T.1.268320723933839]       -0.0948      0.082     -1.162      0.245      -0.255       0.065
# C(Id)[T.1.32717332328263]        -0.9040      0.116     -7.781      0.000      -1.132      -0.676
# C(Id)[T.1.386025922631421]       -1.1108      0.061    -18.125      0.000      -1.231      -0.991
# C(Id)[T.1.444878521980212]        0.1826      0.116      1.580      0.114      -0.044       0.409
# C(Id)[T.1.5625837206777942]       0.3854      0.092      4.193      0.000       0.205       0.566
# C(Id)[T.1.6214363200265853]      -1.0687      0.061    -17.415      0.000      -1.189      -0.948
# C(Id)[T.1.7391415187241672]      -0.2621      0.068     -3.849      0.000      -0.395      -0.129
# BSA                               0.0669      0.037      1.825      0.068      -0.005       0.139
# BSA2                              0.0031      0.003      1.008      0.313      -0.003       0.009
# DURATION                         -0.0680      0.034     -1.995      0.046      -0.135      -0.001
# ==============================================================================
# Omnibus:                      155.503   Durbin-Watson:                   2.313
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1063.646
# Skew:                           1.600   Prob(JB):                    1.08e-231
# Kurtosis:                      10.617   Cond. No.                         302.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (HAC-Panel)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     RD   R-squared:                       0.756
# Model:                            OLS   Adj. R-squared:                  0.717
# Method:                 Least Squares   F-statistic:                     20.14
# Date:                Fri, 05 Mar 2021   Prob (F-statistic):           1.32e-17
# Time:                        13:32:15   Log-Likelihood:                -266.46
# No. Observations:                 374   AIC:                             636.9
# Df Residuals:                     322   BIC:                             841.0
# Df Model:                          51
# Covariance Type:            hac-panel
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        -0.6683      0.158     -4.229      0.000      -0.978      -0.359
# C(Id)[T.-1.438898846110549]       0.7185      0.210      3.419      0.001       0.307       1.130
# C(Id)[T.-1.3800462467617578]     -0.2487      0.453     -0.549      0.583      -1.137       0.639
# C(Id)[T.-1.3211936474129669]      0.1191      0.102      1.167      0.243      -0.081       0.319
# C(Id)[T.-1.2034884487153847]     -0.2106      0.292     -0.721      0.471      -0.783       0.362
# C(Id)[T.-1.1446358493665936]      0.6882      0.260      2.646      0.008       0.178       1.198
# C(Id)[T.-1.0269306506690117]      1.4965      0.142     10.514      0.000       1.218       1.776
# C(Id)[T.-0.9680780513202205]     -0.7622      0.420     -1.817      0.069      -1.585       0.060
# C(Id)[T.-0.9092254519714295]      0.4361      0.144      3.035      0.002       0.154       0.718
# C(Id)[T.-0.8503728526226385]      1.4608      0.293      4.982      0.000       0.886       2.035
# C(Id)[T.-0.7326676539250564]     -0.7038      0.450     -1.564      0.118      -1.586       0.178
# C(Id)[T.-0.6738150545762653]      1.8155      0.298      6.101      0.000       1.232       2.399
# C(Id)[T.-0.6149624552274743]     -0.3035      0.384     -0.790      0.429      -1.056       0.449
# C(Id)[T.-0.5561098558786832]     -0.2250      0.405     -0.556      0.578      -1.018       0.568
# C(Id)[T.-0.4972572565298922]      0.0982      0.374      0.262      0.793      -0.635       0.832
# C(Id)[T.-0.20299425978593702]     0.2353      0.331      0.711      0.477      -0.414       0.884
# C(Id)[T.-0.14414166043714596]    -0.8856      0.485     -1.825      0.068      -1.837       0.065
# C(Id)[T.-0.08528906108835493]     0.9628      0.214      4.500      0.000       0.543       1.382
# C(Id)[T.-0.02643646173956389]    -0.0531      0.298     -0.178      0.859      -0.637       0.531
# C(Id)[T.0.0912687369580182]       0.3754      0.298      1.258      0.208      -0.209       0.960
# C(Id)[T.0.15012133630680924]      0.3215      0.345      0.932      0.351      -0.354       0.997
# C(Id)[T.0.20897393565560027]     -0.2818      0.384     -0.735      0.463      -1.034       0.470
# C(Id)[T.0.2678265350043913]       2.0414      0.358      5.699      0.000       1.339       2.743
# C(Id)[T.0.32667913435318235]     -0.3366      0.349     -0.965      0.335      -1.020       0.347
# C(Id)[T.0.3855317337019734]       1.6874      0.264      6.392      0.000       1.170       2.205
# C(Id)[T.0.5620895317483465]      -0.2865      0.492     -0.582      0.560      -1.251       0.678
# C(Id)[T.0.6209421310971376]       1.7712      0.429      4.130      0.000       0.931       2.612
# C(Id)[T.0.6797947304459286]      -0.4290      0.327     -1.313      0.189      -1.069       0.211
# C(Id)[T.0.7386473297947196]       2.2465      0.273      8.230      0.000       1.712       2.782
# C(Id)[T.0.7974999291435106]      -0.0103      0.187     -0.055      0.956      -0.378       0.357
# C(Id)[T.0.9152051278410928]       3.2674      0.402      8.130      0.000       2.480       4.055
# C(Id)[T.0.9740577271898838]       1.1555      0.149      7.742      0.000       0.863       1.448
# C(Id)[T.1.0329103265386748]      -0.1316      0.173     -0.760      0.447      -0.471       0.208
# C(Id)[T.1.091762925887466]        2.6967      0.316      8.531      0.000       2.077       3.316
# C(Id)[T.1.1506155252362569]       1.6740      0.218      7.687      0.000       1.247       2.101
# C(Id)[T.1.268320723933839]       -0.7350      0.397     -1.853      0.064      -1.512       0.042
# C(Id)[T.1.32717332328263]         0.1110      0.391      0.284      0.777      -0.656       0.878
# C(Id)[T.1.386025922631421]       -0.3206      0.498     -0.644      0.520      -1.296       0.655
# C(Id)[T.1.444878521980212]        0.1804      0.192      0.939      0.348      -0.196       0.557
# C(Id)[T.1.5625837206777942]       0.6081      0.190      3.204      0.001       0.236       0.980
# C(Id)[T.1.6214363200265853]      -0.2160      0.304     -0.710      0.478      -0.812       0.380
# C(Id)[T.1.7391415187241672]       0.7477      0.138      5.408      0.000       0.477       1.019
# BSA                               0.0972      0.049      1.970      0.049       0.000       0.194
# BSA2                              0.0048      0.007      0.675      0.500      -0.009       0.019
# DURATION                         -0.1543      0.070     -2.213      0.027      -0.291      -0.018
# GROWTH                            0.2113      0.083      2.540      0.011       0.048       0.374
# ASA                               0.0929      0.062      1.500      0.134      -0.029       0.214
# Absorbed_slack                    0.1131      0.048      2.340      0.019       0.018       0.208
# Unabsorbed_slack                 -0.0997      0.052     -1.930      0.054      -0.201       0.002
# Absorptive_capacity              -0.0513      0.023     -2.210      0.027      -0.097      -0.006
# Market_commonality                0.0403      0.044      0.924      0.355      -0.045       0.126
# Size                             -0.4393      0.185     -2.374      0.018      -0.802      -0.077
# ==============================================================================
# Omnibus:                       56.605   Durbin-Watson:                   1.203
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              168.520
# Skew:                           0.682   Prob(JB):                     2.55e-37
# Kurtosis:                       5.992   Cond. No.                         485.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (HAC-Panel)
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)            0.015179       -0.000636        0.041066    0.056
# ACME (treated)            0.015179       -0.000636        0.041066    0.056
# ADE (control)             0.099331       -0.010404        0.215866    0.064
# ADE (treated)             0.099331       -0.010404        0.215866    0.064
# Total effect              0.114510        0.004850        0.237785    0.048
# Prop. mediated (control)  0.109743       -0.078067        0.734329    0.088
# Prop. mediated (treated)  0.109743       -0.078067        0.734329    0.088
# ACME (average)            0.015179       -0.000636        0.041066    0.056
# ADE (average)             0.099331       -0.010404        0.215866    0.064
# Prop. mediated (average)  0.109743       -0.078067        0.734329    0.088
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.013054       -0.040822        0.004414    0.216
# ACME (treated)           -0.013054       -0.040822        0.004414    0.216
# ADE (control)            -0.158538       -0.285550       -0.018762    0.016
# ADE (treated)            -0.158538       -0.285550       -0.018762    0.016
# Total effect             -0.171592       -0.305634       -0.027942    0.024
# Prop. mediated (control)  0.070447       -0.034147        0.340204    0.224
# Prop. mediated (treated)  0.070447       -0.034147        0.340204    0.224
# ACME (average)           -0.013054       -0.040822        0.004414    0.216
# ADE (average)            -0.158538       -0.285550       -0.018762    0.016
# Prop. mediated (average)  0.070447       -0.034147        0.340204    0.224

# %% [markdown]
# ## Attention to growth - Quadratic Duration

# %% [markdown]
# ## Attention to -growth - 2 Quadratic terms

# %%
mydata = df[['Id','RD','PRODUCT','GROWTH','GEOGRAPHY','BSA','DURATION','ASA','Absorbed_slack','Unabsorbed_slack','Absorptive_capacity','Market_commonality','Size','Year']]
mydata = mydata.dropna()
mydata = (mydata - mydata.mean()) / mydata.std() 
mydata['BSA2'] = mydata['BSA']*mydata['BSA']
mydata['DURATION2'] = mydata['DURATION']*mydata['DURATION']
mydata = mydata.sort_values(by=['Id','Year'], axis=0, ascending=True)
mediator_model = sm.OLS.from_formula('GROWTH~BSA+BSA2+DURATION+DURATION2+C(Id)', data=mydata)
outcome_model = sm.OLS.from_formula('RD~BSA+BSA2+DURATION+DURATION2+GROWTH+ASA+Absorbed_slack+Unabsorbed_slack+Absorptive_capacity+Market_commonality+Size+C(Id)',data=mydata)        
mediator = mediator_model.fit(cov_type='hac-panel',cov_kwds={'maxlags':1,'groups':mydata['Id']})
outcome = outcome_model.fit(cov_type='hac-panel',cov_kwds={'maxlags':1,'groups':mydata['Id']})
print(mediator.summary())
print(outcome.summary())
BSA_Mediation = Mediation(outcome_model,mediator_model,'BSA','GROWTH').fit(n_rep=250)
print(BSA_Mediation.summary())
Duration_Mediation = Mediation(outcome_model,mediator_model,'DURATION','GROWTH').fit(n_rep=250)
print(Duration_Mediation.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 GROWTH   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.910
# Method:                 Least Squares   F-statistic:                     169.3
# Date:                Fri, 05 Mar 2021   Prob (F-statistic):           1.31e-35
# Time:                        13:16:56   Log-Likelihood:                -56.406
# No. Observations:                 374   AIC:                             204.8
# Df Residuals:                     328   BIC:                             385.3
# Df Model:                          45
# Covariance Type:            hac-panel
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         0.2135      0.058      3.686      0.000       0.100       0.327
# C(Id)[T.-1.438898846110549]       2.0511      0.128     16.005      0.000       1.800       2.302
# C(Id)[T.-1.3800462467617578]      1.3328      0.352      3.790      0.000       0.643       2.022
# C(Id)[T.-1.3211936474129669]     -0.6223      0.073     -8.567      0.000      -0.765      -0.480
# C(Id)[T.-1.2034884487153847]     -0.8753      0.064    -13.620      0.000      -1.001      -0.749
# C(Id)[T.-1.1446358493665936]     -0.4971      0.116     -4.299      0.000      -0.724      -0.270
# C(Id)[T.-1.0269306506690117]     -0.8683      0.057    -15.337      0.000      -0.979      -0.757
# C(Id)[T.-0.9680780513202205]     -0.0615      0.090     -0.685      0.494      -0.238       0.115
# C(Id)[T.-0.9092254519714295]     -1.0319      0.053    -19.413      0.000      -1.136      -0.928
# C(Id)[T.-0.8503728526226385]      1.2732      0.182      7.004      0.000       0.917       1.629
# C(Id)[T.-0.7326676539250564]     -0.4797      0.070     -6.893      0.000      -0.616      -0.343
# C(Id)[T.-0.6738150545762653]     -1.1847      0.052    -22.674      0.000      -1.287      -1.082
# C(Id)[T.-0.6149624552274743]      0.1862      0.133      1.395      0.163      -0.075       0.448
# C(Id)[T.-0.5561098558786832]     -0.7166      0.070    -10.188      0.000      -0.854      -0.579
# C(Id)[T.-0.4972572565298922]     -0.8205      0.064    -12.722      0.000      -0.947      -0.694
# C(Id)[T.-0.20299425978593702]    -0.2680      0.125     -2.152      0.031      -0.512      -0.024
# C(Id)[T.-0.14414166043714596]    -0.7073      0.065    -10.858      0.000      -0.835      -0.580
# C(Id)[T.-0.08528906108835493]    -0.8571      0.056    -15.243      0.000      -0.967      -0.747
# C(Id)[T.-0.02643646173956389]    -0.8600      0.056    -15.278      0.000      -0.970      -0.750
# C(Id)[T.0.0912687369580182]      -0.4771      0.075     -6.339      0.000      -0.625      -0.330
# C(Id)[T.0.15012133630680924]     -0.6047      0.080     -7.571      0.000      -0.761      -0.448
# C(Id)[T.0.20897393565560027]     -0.4697      0.079     -5.965      0.000      -0.624      -0.315
# C(Id)[T.0.2678265350043913]       1.5038      0.286      5.255      0.000       0.943       2.065
# C(Id)[T.0.32667913435318235]     -1.1282      0.062    -18.070      0.000      -1.251      -1.006
# C(Id)[T.0.3855317337019734]       2.2448      0.113     19.912      0.000       2.024       2.466
# C(Id)[T.0.5620895317483465]       1.0445      0.279      3.738      0.000       0.497       1.592
# C(Id)[T.0.6209421310971376]      -0.4501      0.154     -2.932      0.003      -0.751      -0.149
# C(Id)[T.0.6797947304459286]       0.6307      0.430      1.467      0.142      -0.212       1.473
# C(Id)[T.0.7386473297947196]      -1.1727      0.053    -22.250      0.000      -1.276      -1.069
# C(Id)[T.0.7974999291435106]      -1.0430      0.054    -19.444      0.000      -1.148      -0.938
# C(Id)[T.0.9152051278410928]      -0.7249      0.075     -9.651      0.000      -0.872      -0.578
# C(Id)[T.0.9740577271898838]      -0.3912      0.141     -2.771      0.006      -0.668      -0.114
# C(Id)[T.1.0329103265386748]       1.3674      0.159      8.603      0.000       1.056       1.679
# C(Id)[T.1.091762925887466]       -0.7622      0.059    -12.967      0.000      -0.877      -0.647
# C(Id)[T.1.1506155252362569]      -1.1088      0.063    -17.498      0.000      -1.233      -0.985
# C(Id)[T.1.268320723933839]       -0.1006      0.083     -1.216      0.224      -0.263       0.062
# C(Id)[T.1.32717332328263]        -0.8562      0.122     -7.006      0.000      -1.096      -0.617
# C(Id)[T.1.386025922631421]       -1.1199      0.061    -18.434      0.000      -1.239      -1.001
# C(Id)[T.1.444878521980212]        0.1659      0.112      1.481      0.139      -0.054       0.386
# C(Id)[T.1.5625837206777942]       0.3640      0.094      3.862      0.000       0.179       0.549
# C(Id)[T.1.6214363200265853]      -1.0931      0.062    -17.673      0.000      -1.214      -0.972
# C(Id)[T.1.7391415187241672]      -0.2633      0.068     -3.865      0.000      -0.397      -0.130
# BSA                               0.0765      0.039      1.979      0.048       0.001       0.152
# BSA2                              0.0039      0.003      1.205      0.228      -0.002       0.010
# DURATION                         -0.0294      0.046     -0.642      0.521      -0.119       0.060
# DURATION2                        -0.0227      0.016     -1.427      0.154      -0.054       0.008
# ==============================================================================
# Omnibus:                      153.968   Durbin-Watson:                   2.313
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1058.994
# Skew:                           1.579   Prob(JB):                    1.10e-230
# Kurtosis:                      10.615   Cond. No.                         303.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (HAC-Panel)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     RD   R-squared:                       0.756
# Model:                            OLS   Adj. R-squared:                  0.716
# Method:                 Least Squares   F-statistic:                     19.79
# Date:                Fri, 05 Mar 2021   Prob (F-statistic):           1.69e-17
# Time:                        13:16:56   Log-Likelihood:                -266.46
# No. Observations:                 374   AIC:                             638.9
# Df Residuals:                     321   BIC:                             846.9
# Df Model:                          52
# Covariance Type:            hac-panel
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        -0.6708      0.160     -4.206      0.000      -0.983      -0.358
# C(Id)[T.-1.438898846110549]       0.7183      0.210      3.413      0.001       0.306       1.131
# C(Id)[T.-1.3800462467617578]     -0.2458      0.453     -0.542      0.588      -1.134       0.643
# C(Id)[T.-1.3211936474129669]      0.1193      0.102      1.172      0.241      -0.080       0.319
# C(Id)[T.-1.2034884487153847]     -0.2090      0.291     -0.718      0.473      -0.780       0.362
# C(Id)[T.-1.1446358493665936]      0.6891      0.261      2.637      0.008       0.177       1.201
# C(Id)[T.-1.0269306506690117]      1.4970      0.143     10.452      0.000       1.216       1.778
# C(Id)[T.-0.9680780513202205]     -0.7607      0.418     -1.822      0.068      -1.579       0.058
# C(Id)[T.-0.9092254519714295]      0.4367      0.144      3.026      0.002       0.154       0.720
# C(Id)[T.-0.8503728526226385]      1.4577      0.299      4.873      0.000       0.871       2.044
# C(Id)[T.-0.7326676539250564]     -0.7020      0.447     -1.569      0.117      -1.579       0.175
# C(Id)[T.-0.6738150545762653]      1.8160      0.298      6.098      0.000       1.232       2.400
# C(Id)[T.-0.6149624552274743]     -0.3005      0.384     -0.783      0.434      -1.053       0.452
# C(Id)[T.-0.5561098558786832]     -0.2223      0.402     -0.553      0.580      -1.010       0.565
# C(Id)[T.-0.4972572565298922]      0.1013      0.373      0.272      0.786      -0.630       0.833
# C(Id)[T.-0.20299425978593702]     0.2336      0.336      0.694      0.488      -0.426       0.893
# C(Id)[T.-0.14414166043714596]    -0.8840      0.482     -1.832      0.067      -1.830       0.062
# C(Id)[T.-0.08528906108835493]     0.9633      0.214      4.506      0.000       0.544       1.382
# C(Id)[T.-0.02643646173956389]    -0.0520      0.297     -0.175      0.861      -0.634       0.530
# C(Id)[T.0.0912687369580182]       0.3776      0.297      1.271      0.204      -0.205       0.960
# C(Id)[T.0.15012133630680924]      0.3257      0.346      0.942      0.346      -0.352       1.004
# C(Id)[T.0.20897393565560027]     -0.2805      0.382     -0.734      0.463      -1.029       0.469
# C(Id)[T.0.2678265350043913]       2.0411      0.359      5.692      0.000       1.338       2.744
# C(Id)[T.0.32667913435318235]     -0.3331      0.347     -0.959      0.338      -1.014       0.348
# C(Id)[T.0.3855317337019734]       1.6866      0.263      6.408      0.000       1.171       2.202
# C(Id)[T.0.5620895317483465]      -0.2840      0.490     -0.579      0.563      -1.245       0.677
# C(Id)[T.0.6209421310971376]       1.7715      0.430      4.124      0.000       0.930       2.614
# C(Id)[T.0.6797947304459286]      -0.4274      0.327     -1.307      0.191      -1.068       0.214
# C(Id)[T.0.7386473297947196]       2.2468      0.273      8.231      0.000       1.712       2.782
# C(Id)[T.0.7974999291435106]      -0.0094      0.186     -0.050      0.960      -0.374       0.355
# C(Id)[T.0.9152051278410928]       3.2680      0.401      8.156      0.000       2.483       4.053
# C(Id)[T.0.9740577271898838]       1.1579      0.149      7.788      0.000       0.866       1.449
# C(Id)[T.1.0329103265386748]      -0.1319      0.174     -0.756      0.449      -0.474       0.210
# C(Id)[T.1.091762925887466]        2.6968      0.317      8.520      0.000       2.076       3.317
# C(Id)[T.1.1506155252362569]       1.6751      0.218      7.678      0.000       1.247       2.103
# C(Id)[T.1.268320723933839]       -0.7332      0.395     -1.855      0.064      -1.508       0.042
# C(Id)[T.1.32717332328263]         0.1085      0.399      0.272      0.786      -0.674       0.891
# C(Id)[T.1.386025922631421]       -0.3185      0.497     -0.641      0.522      -1.293       0.656
# C(Id)[T.1.444878521980212]        0.1820      0.191      0.953      0.340      -0.192       0.556
# C(Id)[T.1.5625837206777942]       0.6102      0.191      3.192      0.001       0.236       0.985
# C(Id)[T.1.6214363200265853]      -0.2128      0.306     -0.694      0.487      -0.814       0.388
# C(Id)[T.1.7391415187241672]       0.7479      0.138      5.431      0.000       0.478       1.018
# BSA                               0.0964      0.050      1.919      0.055      -0.002       0.195
# BSA2                              0.0047      0.007      0.660      0.509      -0.009       0.019
# DURATION                         -0.1575      0.094     -1.670      0.095      -0.342       0.027
# DURATION2                         0.0019      0.036      0.051      0.959      -0.070       0.073
# GROWTH                            0.2115      0.083      2.540      0.011       0.048       0.375
# ASA                               0.0928      0.062      1.499      0.134      -0.029       0.214
# Absorbed_slack                    0.1130      0.048      2.342      0.019       0.018       0.208
# Unabsorbed_slack                 -0.0993      0.051     -1.938      0.053      -0.200       0.001
# Absorptive_capacity              -0.0513      0.023     -2.207      0.027      -0.097      -0.006
# Market_commonality                0.0403      0.044      0.924      0.355      -0.045       0.126
# Size                             -0.4387      0.184     -2.379      0.017      -0.800      -0.077
# ==============================================================================
# Omnibus:                       56.593   Durbin-Watson:                   1.203
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              168.279
# Skew:                           0.683   Prob(JB):                     2.88e-37
# Kurtosis:                       5.989   Cond. No.                         488.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (HAC-Panel)
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)            0.017124       -0.001593        0.045939    0.072
# ACME (treated)            0.017124       -0.001593        0.045939    0.072
# ADE (control)             0.097161       -0.030229        0.235179    0.152
# ADE (treated)             0.097161       -0.030229        0.235179    0.152
# Total effect              0.114284       -0.011785        0.251070    0.088
# Prop. mediated (control)  0.128259       -1.003637        1.440096    0.160
# Prop. mediated (treated)  0.128259       -1.003637        1.440096    0.160
# ACME (average)            0.017124       -0.001593        0.045939    0.072
# ADE (average)             0.097161       -0.030229        0.235179    0.152
# Prop. mediated (average)  0.128259       -1.003637        1.440096    0.160
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.005352       -0.035990        0.021602    0.624
# ACME (treated)           -0.005352       -0.035990        0.021602    0.624
# ADE (control)            -0.161553       -0.327893        0.043568    0.120
# ADE (treated)            -0.161553       -0.327893        0.043568    0.120
# Total effect             -0.166905       -0.332763        0.041957    0.096
# Prop. mediated (control)  0.025081       -0.249404        0.424271    0.624
# Prop. mediated (treated)  0.025081       -0.249404        0.424271    0.624
# ACME (average)           -0.005352       -0.035990        0.021602    0.624
# ADE (average)            -0.161553       -0.327893        0.043568    0.120
# Prop. mediated (average)  0.025081       -0.249404        0.424271    0.624

# %% [markdown]
# ## Attention to product

# %%
mydata = df[['Id','RD','PRODUCT','GROWTH','GEOGRAPHY','BSA','DURATION','ASA','Absorbed_slack','Unabsorbed_slack','Absorptive_capacity','Market_commonality','Size','Year']]
mydata = mydata.dropna()
mydata = mydata.sort_values(by=['Id','Year'], axis=0, ascending=True)
mediator_model = sm.OLS.from_formula('PRODUCT~BSA+DURATION+C(Id)+C(Year)', data=mydata)
outcome_model = sm.OLS.from_formula('RD~BSA+DURATION+PRODUCT+ASA+Absorbed_slack+Unabsorbed_slack+Absorptive_capacity+Market_commonality+Size+C(Id)+C(Year)',data=mydata)        
mediator = mediator_model.fit(cov_type='hac-panel',cov_kwds={'maxlags':1,'groups':mydata['Id']})
outcome = outcome_model.fit(cov_type='hac-panel',cov_kwds={'maxlags':1,'groups':mydata['Id']})
print(mediator.summary())
print(outcome.summary())
BSA_Mediation = Mediation(outcome_model,mediator_model,'BSA','PRODUCT').fit(n_rep=250)
print(BSA_Mediation.summary())
Duration_Mediation = Mediation(outcome_model,mediator_model,'DURATION','PRODUCT').fit(n_rep=250)
print(Duration_Mediation.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                PRODUCT   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                 1.635e+04
# Date:                Mon, 01 Mar 2021   Prob (F-statistic):           7.44e-77
# Time:                        18:32:07   Log-Likelihood:                 731.55
# No. Observations:                 374   AIC:                            -1341.
# Df Residuals:                     313   BIC:                            -1102.
# Df Model:                          60
# Covariance Type:            hac-panel
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.0046      0.004      1.141      0.254      -0.003       0.013
# C(Id)[T.2]         -0.0011      0.003     -0.378      0.705      -0.007       0.005
# C(Id)[T.3]          0.5942      0.054     10.936      0.000       0.488       0.701
# C(Id)[T.4]          0.0025      0.004      0.687      0.492      -0.005       0.010
# C(Id)[T.6]         -0.0051      0.004     -1.164      0.244      -0.014       0.003
# C(Id)[T.7]          0.8852      0.017     51.722      0.000       0.852       0.919
# C(Id)[T.9]          0.9505      0.005    193.597      0.000       0.941       0.960
# C(Id)[T.10]         0.8114      0.008    102.784      0.000       0.796       0.827
# C(Id)[T.11]         0.9745      0.003    302.777      0.000       0.968       0.981
# C(Id)[T.12]        -0.0212      0.013     -1.680      0.093      -0.046       0.004
# C(Id)[T.14]         0.8863      0.009    100.433      0.000       0.869       0.904
# C(Id)[T.15]         0.9985      0.003    314.083      0.000       0.992       1.005
# C(Id)[T.16]         0.7756      0.018     42.081      0.000       0.739       0.812
# C(Id)[T.17]         0.9309      0.006    168.684      0.000       0.920       0.942
# C(Id)[T.18]         0.9418      0.006    148.424      0.000       0.929       0.954
# C(Id)[T.23]         0.8745      0.014     63.822      0.000       0.848       0.901
# C(Id)[T.24]         0.0212      0.012      1.812      0.070      -0.002       0.044
# C(Id)[T.25]         0.9432      0.004    237.320      0.000       0.935       0.951
# C(Id)[T.26]         0.9450      0.005    209.307      0.000       0.936       0.954
# C(Id)[T.28]         0.8947      0.008    111.849      0.000       0.879       0.910
# C(Id)[T.29]         0.9100      0.007    127.043      0.000       0.896       0.924
# C(Id)[T.30]         0.8902      0.008    110.611      0.000       0.874       0.906
# C(Id)[T.31]         0.0057      0.005      1.099      0.272      -0.004       0.016
# C(Id)[T.32]         0.9943      0.006    168.772      0.000       0.983       1.006
# C(Id)[T.33]        -0.0017      0.004     -0.412      0.681      -0.010       0.006
# C(Id)[T.36]         0.6484      0.042     15.497      0.000       0.566       0.730
# C(Id)[T.37]         0.8779      0.025     34.907      0.000       0.829       0.927
# C(Id)[T.38]         0.7037      0.070     10.105      0.000       0.567       0.840
# C(Id)[T.39]         0.9993      0.004    260.911      0.000       0.992       1.007
# C(Id)[T.40]         0.9728      0.005    195.148      0.000       0.963       0.983
# C(Id)[T.42]         0.9232      0.008    110.468      0.000       0.907       0.940
# C(Id)[T.43]         0.8740      0.023     38.731      0.000       0.830       0.918
# C(Id)[T.44]         0.0006      0.004      0.160      0.873      -0.006       0.008
# C(Id)[T.45]        -0.0057      0.004     -1.351      0.177      -0.014       0.003
# C(Id)[T.46]         0.9938      0.009    116.736      0.000       0.977       1.010
# C(Id)[T.48]         0.8208      0.013     65.052      0.000       0.796       0.846
# C(Id)[T.49]         0.9769      0.013     73.423      0.000       0.951       1.003
# C(Id)[T.50]         0.6548      0.014     47.661      0.000       0.628       0.682
# C(Id)[T.51]        -0.0039      0.005     -0.812      0.417      -0.013       0.005
# C(Id)[T.53]         0.7446      0.013     55.549      0.000       0.718       0.771
# C(Id)[T.54]        -0.0137      0.008     -1.821      0.069      -0.028       0.001
# C(Id)[T.56]         0.8543      0.006    136.491      0.000       0.842       0.867
# C(Year)[T.1996]    -0.0051      0.005     -1.068      0.285      -0.015       0.004
# C(Year)[T.1997]     0.0062      0.005      1.159      0.247      -0.004       0.017
# C(Year)[T.1998]    -0.0076      0.006     -1.305      0.192      -0.019       0.004
# C(Year)[T.1999]    -0.0058      0.009     -0.662      0.508      -0.023       0.011
# C(Year)[T.2000]    -0.0086      0.009     -0.950      0.342      -0.026       0.009
# C(Year)[T.2001]    -0.0014      0.005     -0.300      0.764      -0.011       0.008
# C(Year)[T.2002]    -0.0183      0.014     -1.281      0.200      -0.046       0.010
# C(Year)[T.2003]    -0.0129      0.007     -1.845      0.065      -0.027       0.001
# C(Year)[T.2004]     0.0013      0.006      0.199      0.843      -0.011       0.014
# C(Year)[T.2005]     0.0109      0.008      1.379      0.168      -0.005       0.026
# C(Year)[T.2006]    -0.0164      0.010     -1.692      0.091      -0.035       0.003
# C(Year)[T.2007]    -0.0106      0.009     -1.181      0.238      -0.028       0.007
# C(Year)[T.2008]     0.0022      0.007      0.302      0.763      -0.012       0.017
# C(Year)[T.2009]    -0.0150      0.011     -1.419      0.156      -0.036       0.006
# C(Year)[T.2010]     0.0057      0.008      0.676      0.499      -0.011       0.022
# C(Year)[T.2011]     0.0052      0.006      0.833      0.405      -0.007       0.017
# C(Year)[T.2012]     0.0082      0.006      1.445      0.148      -0.003       0.019
# BSA                -0.0291      0.018     -1.603      0.109      -0.065       0.006
# DURATION            0.0011      0.001      1.432      0.152      -0.000       0.003
# ==============================================================================
# Omnibus:                      211.223   Durbin-Watson:                   2.364
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3522.864
# Skew:                          -1.993   Prob(JB):                         0.00
# Kurtosis:                      17.498   Cond. No.                         213.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (HAC-Panel)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     RD   R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.771
# Method:                 Least Squares   F-statistic:                     20.28
# Date:                Mon, 01 Mar 2021   Prob (F-statistic):           3.78e-18
# Time:                        18:32:07   Log-Likelihood:                -1053.5
# No. Observations:                 374   AIC:                             2243.
# Df Residuals:                     306   BIC:                             2510.
# Df Model:                          67
# Covariance Type:            hac-panel
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept             -15.4273     11.317     -1.363      0.173     -37.609       6.754
# C(Id)[T.2]             11.8828      1.734      6.852      0.000       8.484      15.282
# C(Id)[T.3]             13.3352      5.015      2.659      0.008       3.507      23.164
# C(Id)[T.4]             -1.1442      1.465     -0.781      0.435      -4.015       1.727
# C(Id)[T.6]              5.9322      2.921      2.031      0.042       0.207      11.657
# C(Id)[T.7]             13.3123      6.107      2.180      0.029       1.343      25.282
# C(Id)[T.9]             13.1164      5.872      2.234      0.026       1.607      24.625
# C(Id)[T.10]             6.8598      5.668      1.210      0.226      -4.250      17.970
# C(Id)[T.11]             5.2339      6.000      0.872      0.383      -6.526      16.994
# C(Id)[T.12]            14.8113      2.433      6.089      0.000      10.043      19.579
# C(Id)[T.14]             4.5775      6.250      0.732      0.464      -7.672      16.827
# C(Id)[T.15]            18.2885      6.294      2.906      0.004       5.952      30.625
# C(Id)[T.16]            11.6519      5.585      2.086      0.037       0.706      22.598
# C(Id)[T.17]            10.6573      6.248      1.706      0.088      -1.589      22.903
# C(Id)[T.18]             8.0820      6.304      1.282      0.200      -4.274      20.438
# C(Id)[T.23]            10.4028      5.915      1.759      0.079      -1.191      21.997
# C(Id)[T.24]             7.9400      4.365      1.819      0.069      -0.615      16.495
# C(Id)[T.25]            12.0717      5.876      2.054      0.040       0.555      23.588
# C(Id)[T.26]            10.5803      6.069      1.743      0.081      -1.314      22.474
# C(Id)[T.28]            10.7142      5.824      1.840      0.066      -0.700      22.129
# C(Id)[T.29]            10.3566      5.909      1.753      0.080      -1.224      21.937
# C(Id)[T.30]             9.5541      6.082      1.571      0.116      -2.366      21.474
# C(Id)[T.31]            19.5757      3.116      6.283      0.000      13.469      25.683
# C(Id)[T.32]             2.4417      6.447      0.379      0.705     -10.194      15.077
# C(Id)[T.33]            20.7127      2.000     10.359      0.000      16.794      24.632
# C(Id)[T.36]            11.5528      5.215      2.215      0.027       1.331      21.774
# C(Id)[T.37]            19.8876      5.721      3.477      0.001       8.676      31.100
# C(Id)[T.38]             6.6811      4.610      1.449      0.147      -2.354      15.716
# C(Id)[T.39]            17.8628      6.983      2.558      0.011       4.176      31.549
# C(Id)[T.40]             5.8980      6.101      0.967      0.334      -6.060      17.856
# C(Id)[T.42]            30.2957      6.294      4.813      0.000      17.960      42.632
# C(Id)[T.43]            10.2643      5.565      1.844      0.065      -0.643      21.172
# C(Id)[T.44]             0.0329      1.782      0.018      0.985      -3.460       3.526
# C(Id)[T.45]            24.9185      2.286     10.903      0.000      20.439      29.398
# C(Id)[T.46]            13.3969      6.482      2.067      0.039       0.692      26.102
# C(Id)[T.48]             3.3182      5.620      0.590      0.555      -7.697      14.334
# C(Id)[T.49]            10.0640      6.572      1.531      0.126      -2.818      22.946
# C(Id)[T.50]             8.7163      5.470      1.593      0.111      -2.005      19.438
# C(Id)[T.51]             5.5819      1.804      3.094      0.002       2.046       9.117
# C(Id)[T.53]            12.9554      4.824      2.686      0.007       3.501      22.410
# C(Id)[T.54]             8.9779      3.083      2.912      0.004       2.935      15.020
# C(Id)[T.56]             8.0476      5.398      1.491      0.136      -2.533      18.628
# C(Year)[T.1996]         4.6161      2.354      1.961      0.050       0.003       9.229
# C(Year)[T.1997]         8.1837      2.356      3.474      0.001       3.566      12.801
# C(Year)[T.1998]         7.1000      2.628      2.702      0.007       1.949      12.251
# C(Year)[T.1999]         6.6416      2.320      2.863      0.004       2.094      11.189
# C(Year)[T.2000]         5.4167      2.184      2.480      0.013       1.137       9.697
# C(Year)[T.2001]         5.7229      2.102      2.722      0.006       1.603       9.843
# C(Year)[T.2002]         3.2023      1.851      1.730      0.084      -0.426       6.830
# C(Year)[T.2003]         3.5340      1.943      1.819      0.069      -0.274       7.342
# C(Year)[T.2004]         2.4527      1.895      1.295      0.195      -1.260       6.166
# C(Year)[T.2005]         3.1995      1.991      1.607      0.108      -0.702       7.101
# C(Year)[T.2006]         2.6593      1.933      1.376      0.169      -1.130       6.448
# C(Year)[T.2007]         2.1872      1.875      1.166      0.244      -1.488       5.863
# C(Year)[T.2008]        -0.5347      1.926     -0.278      0.781      -4.310       3.241
# C(Year)[T.2009]        -0.5436      2.009     -0.271      0.787      -4.482       3.395
# C(Year)[T.2010]        -2.8858      2.007     -1.438      0.150      -6.819       1.047
# C(Year)[T.2011]        -1.9136      2.055     -0.931      0.352      -5.942       2.114
# C(Year)[T.2012]        -2.7180      2.184     -1.245      0.213      -6.998       1.562
# BSA                     5.3062      1.657      3.201      0.001       2.058       8.555
# DURATION               -0.1338      0.106     -1.264      0.206      -0.341       0.074
# PRODUCT                -0.6403      6.024     -0.106      0.915     -12.446      11.166
# ASA                     8.1147      2.721      2.983      0.003       2.782      13.447
# Absorbed_slack          3.9815      2.372      1.679      0.093      -0.667       8.630
# Unabsorbed_slack       -0.2430      0.281     -0.865      0.387      -0.793       0.307
# Absorptive_capacity    -1.7804      1.074     -1.658      0.097      -3.886       0.325
# Market_commonality      1.8055      2.360      0.765      0.444      -2.820       6.431
# Size                    0.9616      1.041      0.924      0.356      -1.079       3.002
# ==============================================================================
# Omnibus:                       45.059   Durbin-Watson:                   1.409
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              103.499
# Skew:                           0.620   Prob(JB):                     3.35e-23
# Kurtosis:                       5.259   Cond. No.                     1.70e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (HAC-Panel)
# [2] The condition number is large, 1.7e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)            0.010500       -0.534254        0.530300    0.992
# ACME (treated)            0.010500       -0.534254        0.530300    0.992
# ADE (control)             5.222587        1.496357        9.739662    0.024
# ADE (treated)             5.222587        1.496357        9.739662    0.024
# Total effect              5.233087        1.480612        9.711033    0.016
# Prop. mediated (control)  0.000067       -0.125564        0.124834    0.992
# Prop. mediated (treated)  0.000067       -0.125564        0.124834    0.992
# ACME (average)            0.010500       -0.534254        0.530300    0.992
# ADE (average)             5.222587        1.496357        9.739662    0.024
# Prop. mediated (average)  0.000067       -0.125564        0.124834    0.992
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.000163       -0.060130        0.062855    0.992
# ACME (treated)           -0.000163       -0.060130        0.062855    0.992
# ADE (control)            -0.135090       -0.415689        0.127800    0.288
# ADE (treated)            -0.135090       -0.415689        0.127800    0.288
# Total effect             -0.135252       -0.416500        0.126998    0.296
# Prop. mediated (control)  0.000329       -1.109845        1.264621    0.968
# Prop. mediated (treated)  0.000329       -1.109845        1.264621    0.968
# ACME (average)           -0.000163       -0.060130        0.062855    0.992
# ADE (average)            -0.135090       -0.415689        0.127800    0.288
# Prop. mediated (average)  0.000329       -1.109845        1.264621    0.968

# %% [markdown]
# ## Attention to geography

# %%
mydata = df[['Id','RD','PRODUCT','GROWTH','GEOGRAPHY','BSA','DURATION','ASA','Absorbed_slack','Unabsorbed_slack','Absorptive_capacity','Market_commonality','Size','Year']]
mydata = mydata.dropna()
mydata = mydata.sort_values(by=['Id','Year'], axis=0, ascending=True)
mediator_model = sm.OLS.from_formula('GEOGRAPHY~BSA+DURATION+C(Id)+C(Year)', data=mydata)
outcome_model = sm.OLS.from_formula('RD~BSA+DURATION+GEOGRAPHY+ASA+Absorbed_slack+Unabsorbed_slack+Absorptive_capacity+Market_commonality+Size+C(Id)+C(Year)',data=mydata)        
mediator = mediator_model.fit(cov_type='hac-panel',cov_kwds={'maxlags':1,'groups':mydata['Id']})
outcome = outcome_model.fit(cov_type='hac-panel',cov_kwds={'maxlags':1,'groups':mydata['Id']})
print(mediator.summary())
print(outcome.summary())
BSA_Mediation = Mediation(outcome_model,mediator_model,'BSA','GEOGRAPHY').fit(n_rep=250)
print(BSA_Mediation.summary())
Duration_Mediation = Mediation(outcome_model,mediator_model,'DURATION','GEOGRAPHY').fit(n_rep=250)
print(Duration_Mediation.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              GEOGRAPHY   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     9760.
# Date:                Mon, 01 Mar 2021   Prob (F-statistic):           2.92e-72
# Time:                        18:34:14   Log-Likelihood:                 779.88
# No. Observations:                 374   AIC:                            -1438.
# Df Residuals:                     313   BIC:                            -1198.
# Df Model:                          60
# Covariance Type:            hac-panel
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.7862      0.019     40.736      0.000       0.748       0.824
# C(Id)[T.2]         -0.3403      0.018    -18.639      0.000      -0.376      -0.304
# C(Id)[T.3]         -0.8244      0.012    -68.578      0.000      -0.848      -0.801
# C(Id)[T.4]          0.1074      0.013      8.365      0.000       0.082       0.133
# C(Id)[T.6]          0.1480      0.009     16.190      0.000       0.130       0.166
# C(Id)[T.7]         -0.8042      0.008   -101.609      0.000      -0.820      -0.789
# C(Id)[T.9]         -0.8005      0.008   -103.068      0.000      -0.816      -0.785
# C(Id)[T.10]        -0.8023      0.010    -83.528      0.000      -0.821      -0.783
# C(Id)[T.11]        -0.8039      0.008   -100.801      0.000      -0.820      -0.788
# C(Id)[T.12]        -0.1802      0.027     -6.583      0.000      -0.234      -0.127
# C(Id)[T.14]        -0.7996      0.008   -102.727      0.000      -0.815      -0.784
# C(Id)[T.15]        -0.8040      0.008   -102.981      0.000      -0.819      -0.789
# C(Id)[T.16]        -0.8180      0.010    -78.794      0.000      -0.838      -0.798
# C(Id)[T.17]        -0.8141      0.009    -94.220      0.000      -0.831      -0.797
# C(Id)[T.18]        -0.8043      0.008    -95.561      0.000      -0.821      -0.788
# C(Id)[T.23]        -0.8204      0.015    -56.324      0.000      -0.849      -0.792
# C(Id)[T.24]         0.0869      0.015      5.890      0.000       0.058       0.116
# C(Id)[T.25]        -0.8065      0.008    -99.801      0.000      -0.822      -0.791
# C(Id)[T.26]        -0.8109      0.009    -88.121      0.000      -0.829      -0.793
# C(Id)[T.28]        -0.8109      0.009    -87.900      0.000      -0.829      -0.793
# C(Id)[T.29]        -0.8135      0.010    -78.069      0.000      -0.834      -0.793
# C(Id)[T.30]        -0.8121      0.008    -98.830      0.000      -0.828      -0.796
# C(Id)[T.31]        -0.2456      0.046     -5.390      0.000      -0.335      -0.156
# C(Id)[T.32]        -0.8029      0.008    -95.302      0.000      -0.819      -0.786
# C(Id)[T.33]        -0.3774      0.016    -23.601      0.000      -0.409      -0.346
# C(Id)[T.36]        -0.8152      0.012    -65.931      0.000      -0.839      -0.791
# C(Id)[T.37]        -0.8124      0.010    -84.669      0.000      -0.831      -0.794
# C(Id)[T.38]        -0.8102      0.010    -82.690      0.000      -0.829      -0.791
# C(Id)[T.39]        -0.8000      0.008   -104.618      0.000      -0.815      -0.785
# C(Id)[T.40]        -0.8092      0.009    -85.410      0.000      -0.828      -0.791
# C(Id)[T.42]        -0.8052      0.008   -100.498      0.000      -0.821      -0.789
# C(Id)[T.43]        -0.8018      0.008    -97.133      0.000      -0.818      -0.786
# C(Id)[T.44]        -0.2260      0.026     -8.792      0.000      -0.276      -0.176
# C(Id)[T.45]         0.1284      0.008     15.232      0.000       0.112       0.145
# C(Id)[T.46]        -0.8083      0.009    -86.080      0.000      -0.827      -0.790
# C(Id)[T.48]        -0.8022      0.008    -99.502      0.000      -0.818      -0.786
# C(Id)[T.49]        -0.8217      0.015    -53.317      0.000      -0.852      -0.791
# C(Id)[T.50]        -0.4654      0.015    -31.844      0.000      -0.494      -0.437
# C(Id)[T.51]        -0.0231      0.017     -1.338      0.181      -0.057       0.011
# C(Id)[T.53]        -0.8102      0.008    -96.509      0.000      -0.827      -0.794
# C(Id)[T.54]         0.1766      0.008     21.044      0.000       0.160       0.193
# C(Id)[T.56]        -0.8050      0.007   -108.057      0.000      -0.820      -0.790
# C(Year)[T.1996]     0.0109      0.016      0.682      0.495      -0.021       0.042
# C(Year)[T.1997]     0.0112      0.019      0.597      0.550      -0.026       0.048
# C(Year)[T.1998]     0.0078      0.019      0.415      0.678      -0.029       0.045
# C(Year)[T.1999]     0.0150      0.018      0.817      0.414      -0.021       0.051
# C(Year)[T.2000]     0.0044      0.020      0.219      0.827      -0.035       0.044
# C(Year)[T.2001]     0.0098      0.022      0.457      0.648      -0.032       0.052
# C(Year)[T.2002]     0.0202      0.019      1.042      0.297      -0.018       0.058
# C(Year)[T.2003]     0.0169      0.019      0.903      0.367      -0.020       0.054
# C(Year)[T.2004]     0.0179      0.019      0.959      0.337      -0.019       0.054
# C(Year)[T.2005]     0.0267      0.019      1.408      0.159      -0.010       0.064
# C(Year)[T.2006]     0.0003      0.022      0.014      0.989      -0.042       0.043
# C(Year)[T.2007]     0.0266      0.018      1.442      0.149      -0.010       0.063
# C(Year)[T.2008]     0.0284      0.019      1.517      0.129      -0.008       0.065
# C(Year)[T.2009]     0.0285      0.019      1.486      0.137      -0.009       0.066
# C(Year)[T.2010]     0.0305      0.019      1.615      0.106      -0.007       0.068
# C(Year)[T.2011]     0.0348      0.020      1.713      0.087      -0.005       0.075
# C(Year)[T.2012]     0.0273      0.019      1.467      0.142      -0.009       0.064
# BSA                -0.0187      0.008     -2.445      0.014      -0.034      -0.004
# DURATION            0.0006      0.001      0.709      0.478      -0.001       0.002
# ==============================================================================
# Omnibus:                      226.314   Durbin-Watson:                   2.116
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5253.963
# Skew:                          -2.075   Prob(JB):                         0.00
# Kurtosis:                      20.886   Cond. No.                         213.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (HAC-Panel)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     RD   R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.771
# Method:                 Least Squares   F-statistic:                     20.52
# Date:                Mon, 01 Mar 2021   Prob (F-statistic):           3.03e-18
# Time:                        18:34:14   Log-Likelihood:                -1053.4
# No. Observations:                 374   AIC:                             2243.
# Df Residuals:                     306   BIC:                             2510.
# Df Model:                          67
# Covariance Type:            hac-panel
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept             -12.2189     12.385     -0.987      0.324     -36.493      12.055
# C(Id)[T.2]             10.5831      2.535      4.175      0.000       5.615      15.552
# C(Id)[T.3]              9.7623      6.986      1.397      0.162      -3.930      23.455
# C(Id)[T.4]             -0.7283      1.691     -0.431      0.667      -4.043       2.587
# C(Id)[T.6]              6.4529      3.087      2.090      0.037       0.402      12.504
# C(Id)[T.7]              9.6210      6.221      1.546      0.122      -2.572      21.814
# C(Id)[T.9]              9.4214      5.841      1.613      0.107      -2.026      20.869
# C(Id)[T.10]             3.2193      6.409      0.502      0.615      -9.342      15.781
# C(Id)[T.11]             1.5212      5.839      0.261      0.794      -9.924      12.966
# C(Id)[T.12]            14.1621      2.714      5.217      0.000       8.842      19.482
# C(Id)[T.14]             0.8791      6.535      0.135      0.893     -11.929      13.688
# C(Id)[T.15]            14.5481      5.889      2.470      0.013       3.006      26.090
# C(Id)[T.16]             7.9562      6.668      1.193      0.233      -5.113      21.025
# C(Id)[T.17]             6.8818      6.500      1.059      0.290      -5.857      19.621
# C(Id)[T.18]             4.3461      6.328      0.687      0.492      -8.057      16.749
# C(Id)[T.23]             6.6497      6.424      1.035      0.301      -5.942      19.241
# C(Id)[T.24]             8.1620      4.421      1.846      0.065      -0.502      16.826
# C(Id)[T.25]             8.3572      5.759      1.451      0.147      -2.931      19.645
# C(Id)[T.26]             6.8254      6.196      1.102      0.271      -5.319      18.970
# C(Id)[T.28]             6.9943      6.312      1.108      0.268      -5.376      19.365
# C(Id)[T.29]             6.6096      6.280      1.052      0.293      -5.699      18.919
# C(Id)[T.30]             5.8040      6.575      0.883      0.377      -7.082      18.690
# C(Id)[T.31]            18.6217      3.079      6.049      0.000      12.588      24.656
# C(Id)[T.32]            -1.3057      6.173     -0.212      0.832     -13.404      10.793
# C(Id)[T.33]            19.2595      3.469      5.551      0.000      12.460      26.059
# C(Id)[T.36]             7.9285      6.926      1.145      0.252      -5.645      21.502
# C(Id)[T.37]            16.2011      6.945      2.333      0.020       2.588      29.814
# C(Id)[T.38]             3.0863      6.274      0.492      0.623      -9.210      15.382
# C(Id)[T.39]            14.1675      6.162      2.299      0.021       2.090      26.245
# C(Id)[T.40]             2.1504      5.775      0.372      0.710      -9.169      13.469
# C(Id)[T.42]            26.6263      6.463      4.120      0.000      13.959      39.294
# C(Id)[T.43]             6.6286      5.652      1.173      0.241      -4.449      17.706
# C(Id)[T.44]            -0.8030      2.310     -0.348      0.728      -5.330       3.724
# C(Id)[T.45]            25.4116      2.473     10.274      0.000      20.564      30.259
# C(Id)[T.46]             9.6783      5.936      1.630      0.103      -1.957      21.313
# C(Id)[T.48]            -0.3381      6.381     -0.053      0.958     -12.845      12.169
# C(Id)[T.49]             6.2345      6.841      0.911      0.362      -7.174      19.643
# C(Id)[T.50]             6.4152      5.282      1.215      0.225      -3.937      16.767
# C(Id)[T.51]             5.4970      1.817      3.026      0.002       1.936       9.058
# C(Id)[T.53]             9.3595      5.942      1.575      0.115      -2.287      21.006
# C(Id)[T.54]             9.5956      3.278      2.928      0.003       3.172      16.020
# C(Id)[T.56]             4.4154      5.617      0.786      0.432      -6.594      15.425
# C(Year)[T.1996]         4.6642      2.365      1.972      0.049       0.029       9.300
# C(Year)[T.1997]         8.2176      2.367      3.472      0.001       3.579      12.856
# C(Year)[T.1998]         7.1339      2.634      2.708      0.007       1.971      12.297
# C(Year)[T.1999]         6.6992      2.329      2.876      0.004       2.134      11.264
# C(Year)[T.2000]         5.4345      2.195      2.476      0.013       1.132       9.737
# C(Year)[T.2001]         5.7649      2.104      2.740      0.006       1.642       9.888
# C(Year)[T.2002]         3.2922      1.870      1.761      0.078      -0.373       6.957
# C(Year)[T.2003]         3.6117      1.962      1.841      0.066      -0.233       7.456
# C(Year)[T.2004]         2.5250      1.913      1.320      0.187      -1.225       6.275
# C(Year)[T.2005]         3.2988      2.010      1.641      0.101      -0.641       7.238
# C(Year)[T.2006]         2.6745      1.944      1.376      0.169      -1.135       6.484
# C(Year)[T.2007]         2.2993      1.904      1.208      0.227      -1.432       6.031
# C(Year)[T.2008]        -0.4231      1.944     -0.218      0.828      -4.234       3.388
# C(Year)[T.2009]        -0.4191      2.035     -0.206      0.837      -4.407       3.569
# C(Year)[T.2010]        -2.7669      2.035     -1.360      0.174      -6.755       1.221
# C(Year)[T.2011]        -1.7764      2.065     -0.860      0.390      -5.823       2.270
# C(Year)[T.2012]        -2.6134      2.203     -1.186      0.235      -6.931       1.704
# BSA                     5.2541      1.647      3.189      0.001       2.025       8.483
# DURATION               -0.1328      0.106     -1.255      0.209      -0.340       0.075
# GEOGRAPHY              -3.8274      6.839     -0.560      0.576     -17.232       9.577
# ASA                     8.1147      2.723      2.980      0.003       2.778      13.452
# Absorbed_slack          4.0030      2.370      1.689      0.091      -0.642       8.648
# Unabsorbed_slack       -0.2473      0.277     -0.894      0.371      -0.789       0.295
# Absorptive_capacity    -1.7121      1.078     -1.589      0.112      -3.824       0.400
# Market_commonality      1.7465      2.425      0.720      0.471      -3.006       6.499
# Size                    0.9445      1.027      0.920      0.358      -1.068       2.957
# ==============================================================================
# Omnibus:                       45.289   Durbin-Watson:                   1.406
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              104.977
# Skew:                           0.620   Prob(JB):                     1.60e-23
# Kurtosis:                       5.280   Cond. No.                     1.78e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (HAC-Panel)
# [2] The condition number is large, 1.78e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)            0.091867       -0.188116        0.561961    0.640
# ACME (treated)            0.091867       -0.188116        0.561961    0.640
# ADE (control)             5.314003        1.452944        8.963105    0.024
# ADE (treated)             5.314003        1.452944        8.963105    0.024
# Total effect              5.405870        1.537322        9.191582    0.024
# Prop. mediated (control)  0.008085       -0.048001        0.108134    0.664
# Prop. mediated (treated)  0.008085       -0.048001        0.108134    0.664
# ACME (average)            0.091867       -0.188116        0.561961    0.640
# ADE (average)             5.314003        1.452944        8.963105    0.024
# Prop. mediated (average)  0.008085       -0.048001        0.108134    0.664
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.002691       -0.062884        0.041695    0.912
# ACME (treated)           -0.002691       -0.062884        0.041695    0.912
# ADE (control)            -0.131499       -0.391954        0.110981    0.312
# ADE (treated)            -0.131499       -0.391954        0.110981    0.312
# Total effect             -0.134190       -0.387294        0.098419    0.312
# Prop. mediated (control)  0.004503       -0.802048        0.966712    0.936
# Prop. mediated (treated)  0.004503       -0.802048        0.966712    0.936
# ACME (average)           -0.002691       -0.062884        0.041695    0.912
# ADE (average)            -0.131499       -0.391954        0.110981    0.312
# Prop. mediated (average)  0.004503       -0.802048        0.966712    0.936
