# %%
import pandas
import numpy
from numpy import std, correlate, sqrt
from scipy.stats import pearsonr
import statsmodels.api as sm
from statsmodels.stats.mediation import Mediation

# %% [markdown]
# ### Preparing data

# %%
filepath = 'D:/DEA/Data/Original_data.txt'
data = pandas.read_csv(filepath,sep='\t')
data.rename(columns={'origi':'Id'},inplace=True)
print(data.shape,'from 2019_05_25_Results.xlxs')
print(data.Year.unique(),'Years')
print(data.Id.nunique(),'Number of firms')
filepath = 'D:/DEA/Data/Database_secondreviewJIBS.dta' #
data1 = pandas.read_stata(filepath)
data1.rename(columns={'id':'Id','year':'Year','country':'Country'},inplace=True)
data1 = data1[['Id','Year','Country']]
data1['Year'] = pandas.to_numeric(data1.Year.astype(str).str[0:4])
print(data1.shape,'to get country')
data = pandas.merge(left=data,right=data1,how='left',on=['Year','Id'])
print(data.Country.unique())
filepath = 'D:/DEA/Data/2019_05_25_Results_updated.txt'
data2 = pandas.read_csv(filepath,sep='\t')
print(data2.shape,'correction by Elio of market commonality')
data2.rename(columns={'origi':'Id'},inplace=True)
data2 = data2[['Id','Year','Market_commonality']]
data.drop('Market_commonality',axis=1,inplace = True)
data = pandas.merge(left=data,right=data2,how='inner',on=['Year','Id'])
print(data.Non_RD_alliances.sum(),'Total number of Non-RD alliances')
print(data.RD_alliances.sum(),'Total number of RD alliances')
# Out:
# (1232, 33) from 2019_05_25_Results.xlxs
# [1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004
#  2005 2006 2007 2008 2009 2010 2011 2012] Years
# 56 Number of firms
# (1539, 3) to get country
# [nan 'USA' 'Switzerland' 'Netherlands' 'Germany' 'South Africa' 'Japan'
#  'United Kingdom' 'France' 'Australia' 'Ireland' 'Spain' 'Denmark'
#  'Sweden']
# (1232, 34) correction by Elio of market commonality
# 4089.0 Total number of Non-RD alliances
# 7676.0 Total number of RD alliances

# %% [markdown]
# ### Creating variables

# %%
df = data.copy()
df = df.sort_values(by=['Id','Year'],axis=0,ascending=True)
# ASPIRATIONS
df['SA']=df.groupby(['Year']).ROE.transform('mean')
df['distance'] = df['ROE'] - df['SA']
df.loc[df.distance<0,'BSA']=df['distance']
df.loc[(df.distance>0)|(df.distance==0),'BSA']=0
df.loc[(df.distance>0)|(df.distance==0),'ASA']=df['distance']
df.loc[df.distance<0,'ASA']=0
# DURATION
df['DURATION'] = 0
mylist = []
for firm in range(df.Id.nunique()):
  mylist.append(df.loc[df.Id==firm+1,['Id','Year','BSA','DURATION']].values.tolist())
m = [0]
for firm in range(df.Id.nunique()):
  for i in mylist[firm]: 
    if i[2]<0:
      m.append([i[0],i[1],m[-1][2]+1])
    else:
      m.append([i[0],i[1],i[3]])
del m[0]
print(len(m))
mydf = pandas.DataFrame(m,columns=['Id','Year','DURATION'])
df = df.drop('DURATION',axis=1)
df = pandas.merge(left=df,right=mydf,how='inner',on=['Year','Id'])
print(df.loc[(df.Id==38)|(df.Id==39),['Id','Year','BSA','DURATION']])
df = df.sort_values(by=['Id','Year'], axis=0, ascending=True)
#df['BSA'] = df.groupby(['Id'])['BSA'].shift(1)
#df['ASA'] = df.groupby(['Id'])['ASA'].shift(1)
#df['DURATION'] = df.groupby(['Id'])['DURATION'].shift(1)
# ATTENTION
filepath = 'D:/DEA/Data/Results_def_01_for_Elio.txt'
data5 = pandas.read_csv(filepath,sep='\t')
data5 = data5.iloc[1:1008,[0,1,25,26,27]]
data5.columns = ['Year','Id','PRODUCT','GEOGRAPHY','GROWTH']
data5['Year'] = pandas.to_numeric(data5.Year.astype(str).str[0:4])
print(data5)
df = pandas.merge(left=df,right=data5,how='inner',on=['Year','Id'])
df['ATTENTION'] = df[['PRODUCT','GEOGRAPHY','GROWTH']].std(axis=1)
# AMBIDEXTERITY
print(df.Non_RD_alliances.corr(df.RD_alliances),'correlation between RD alliances and non-RD alliances')
df['RD'] = df.RD_alliances
# SIZE
df['Size'] = numpy.log(df.Employees) 
df = df.sort_values(by=['Id','Year'], axis=0, ascending=True)
df[17:30]
# Out:
# 1232
#      Id  Year       BSA  DURATION
# 814  38  1991  0.000000       0.0
# 815  38  1992  0.000000       0.0
# 816  38  1993  0.000000       0.0
# 817  38  1994  0.000000       0.0
# 818  38  1995 -0.014391       1.0
# 819  38  1996 -0.098000       2.0
# 820  38  1997  0.000000       0.0
# 821  38  1998 -0.209075       1.0
# 822  38  1999 -0.059585       2.0
# 823  38  2000 -0.124833       3.0
# 824  38  2001 -0.008870       4.0
# 825  38  2002  0.000000       0.0
# 826  38  2003  0.000000       0.0
# 827  38  2004 -0.045434       1.0
# 828  38  2005 -0.000642       2.0
# 829  38  2006 -0.000154       3.0
# 830  38  2007 -0.634098       4.0
# 831  38  2008 -0.259360       5.0
# 832  38  2009 -0.163826       6.0
# 833  38  2010 -0.089444       7.0
# 834  38  2011 -0.104333       8.0
# 835  38  2012 -0.025738       9.0
# 836  39  1991       NaN       0.0
# 837  39  1992       NaN       0.0
# 838  39  1993       NaN       0.0
# 839  39  1994       NaN       0.0
# 840  39  1995       NaN       0.0
# 841  39  1996 -0.111000       1.0
# 842  39  1997  0.000000       0.0
# 843  39  1998 -0.122075       1.0
# 844  39  1999  0.000000       0.0
# 845  39  2000  0.000000       0.0
# 846  39  2001 -0.028870       1.0
# 847  39  2002  0.000000       0.0
# 848  39  2003  0.000000       0.0
# 849  39  2004  0.000000       0.0
# 850  39  2005 -0.048642       1.0
# 851  39  2006  0.000000       0.0
# 852  39  2007 -0.057098       1.0
# 853  39  2008 -0.029360       2.0
# 854  39  2009 -0.091826       3.0
# 855  39  2010 -0.044444       4.0
# 856  39  2011 -0.119333       5.0
# 857  39  2012 -0.079738       6.0
#       Year  Id  PRODUCT  GEOGRAPHY    GROWTH
# 1     1995   2     0.00   0.339996  0.660004
# 2     1995   3      NaN        NaN       NaN
# 3     1995   4      NaN        NaN       NaN
# 4     1995   5      NaN        NaN       NaN
# 5     1995   6      NaN        NaN       NaN
# ...    ...  ..      ...        ...       ...
# 1003  2012  52     0.75   0.075352  0.170363
# 1004  2012  53     0.83   0.000000  0.167799
# 1005  2012  54     0.00   0.997644  0.002356
# 1006  2012  55      NaN        NaN       NaN
# 1007  2012  56      NaN        NaN       NaN
#
# [1007 rows x 5 columns]
# 0.7259338699988971 correlation between RD alliances and non-RD alliances
#     Id  Year    Age  Employees Total_assets  Net_sales  Human_resources_1  \
# 17   2  1995  107.0    50241.0     9412.580  10012.194              0.199
# 18   2  1996  108.0    52817.0    11125.600  11013.460              0.209
# 19   2  1997  109.0    54487.0    12061.068  11883.462              0.218
# 20   2  1998  110.0    56236.0    13216.213  12477.845              0.222
# 21   2  1999  111.0    57100.0    14471.044  13177.625              0.231
# 22   2  2000  112.0    60571.0    15283.254  13745.916              0.227
# 23   2  2001  113.0    71426.0    23296.423  16285.246              0.228
# 24   2  2002  114.0    71819.0    24259.102  17684.663              0.246
# 25   2  2003  115.0    72181.0    26715.342  19680.561              0.273
# 26   2  2004  116.0    60600.0    28767.494  19680.016              0.325
# 27   2  2005  117.0    59735.0    29141.203  22287.808              0.373
# 28   2  2006  118.0    66663.0    36178.172  22476.322              0.337
# 29   2  2007  119.0    68000.0    39713.924  25914.238              0.381
#
#     Human_resources_2  Physical_resources_1  Physical_resources_2  ...  \
# 17              5.018              4249.538                 0.424  ...
# 18              4.796              4461.543                 0.405  ...
# 19              4.585              4569.691                 0.385  ...
# 20              4.507              4738.843                 0.380  ...
# 21              4.333              4770.059                 0.362  ...
# 22              4.406              4816.911                 0.350  ...
# 23              4.386              5551.547                 0.341  ...
# 24              4.061              5828.122                 0.330  ...
# 25              3.668              6281.806                 0.319  ...
# 26              3.079              6007.874                 0.305  ...
# 27              2.680              6003.141                 0.269  ...
# 28              2.966              6946.435                 0.309  ...
# 29              2.624              7518.149                 0.290  ...
#
#     distance       BSA       ASA  DURATION  PRODUCT  GEOGRAPHY    GROWTH  \
# 17  0.203609  0.000000  0.203609       0.0      0.0   0.339996  0.660004
# 18  0.196000  0.000000  0.196000       0.0      0.0   0.407071  0.592929
# 19  0.289423  0.000000  0.289423       0.0      0.0   0.440513  0.559487
# 20  0.089925  0.000000  0.089925       0.0      0.0   0.430937  0.569063
# 21  0.141415  0.000000  0.141415       0.0      0.0   0.435399  0.564601
# 22  0.167167  0.000000  0.167167       0.0      0.0   0.448690  0.551310
# 23 -0.023870 -0.023870  0.000000       1.0      0.0   0.299710  0.700290
# 24  0.121444  0.000000  0.121444       0.0      0.0   0.534176  0.465824
# 25  0.058906  0.000000  0.058906       0.0      0.0   0.504841  0.495159
# 26  0.070566  0.000000  0.070566       0.0      0.0   0.479917  0.520083
# 27 -0.000642 -0.000642  0.000000       1.0      0.0   0.513522  0.486478
# 28 -0.010154 -0.010154  0.000000       2.0      0.0   0.432130  0.567870
# 29 -0.097098 -0.097098  0.000000       3.0      0.0   0.502678  0.497322
#
#     ATTENTION    RD       Size
# 17   0.330052   9.0  10.824587
# 18   0.303264  12.0  10.874588
# 19   0.294741  23.0  10.905717
# 20   0.296821  11.0  10.937312
# 21   0.295815  13.0  10.952559
# 22   0.293200  25.0  11.011572
# 23   0.351354  21.0  11.176417
# 24   0.290691  12.0  11.181904
# 25   0.288716   9.0  11.186932
# 26   0.289373  21.0  11.012050
# 27   0.288992   9.0  10.997673
# 28   0.296546  12.0  11.107405
# 29   0.288688   9.0  11.127263
#
# [13 rows x 45 columns]

# %% [markdown]
# ### Correlation

# %%
mydata = df[['RD','BSA','DURATION','GROWTH','ASA','Absorbed_slack','Unabsorbed_slack','Absorptive_capacity','Market_commonality','Size','Year']]
print(len(mydata),'Number of observations')
ds_mean = mydata.agg(['mean','std']).T
corr = mydata.corr()
corr = pandas.concat([ds_mean,corr], axis = 1)
corr = corr.applymap('{:.2f}'.format)
corr['statistics'] = ' '
corr.set_index('statistics',append=True,inplace=True)
print(corr)

def pearsonr_pval(x,y):
  return pearsonr(x,y)[1].round(3)
pval = mydata.corr(method=pearsonr_pval)
pval = pval.applymap('{:.3f}'.format)
pval = pval.applymap(lambda x: '(' + x + ')')
pval['statistics'] = 'p-value'
pval.set_index('statistics',append=True,inplace=True)

corr = pandas.concat([corr,pval],axis=0).sort_index(kind='merge').reindex(['RD','BSA','DURATION','GROWTH','ASA','Absorbed_slack','Unabsorbed_slack','Absorptive_capacity','Market_commonality','Size','Year'],axis=0,level=0)
filepath = 'D:/DEA/DEA-2/Correlation-0.txt'
corr.to_csv(filepath,sep = '\t',header=False,index=False)
corr
# Out:
# 1007 Number of observations
#                                    mean    std     RD    BSA DURATION GROWTH  \
#                     statistics
# RD                                 8.04   8.55   1.00   0.14    -0.20   0.06
# BSA                               -0.10   0.21   0.14   1.00    -0.19   0.05
# DURATION                           3.67   6.52  -0.20  -0.19     1.00  -0.02
# GROWTH                             0.15   0.16   0.06   0.05    -0.02   1.00
# ASA                                0.10   0.33   0.06   0.14    -0.18   0.11
# Absorbed_slack                     1.97  37.88  -0.04  -0.06    -0.01  -0.19
# Unabsorbed_slack                   1.39   1.99  -0.18  -0.16     0.06  -0.09
# Absorptive_capacity                0.23   0.72  -0.07  -0.46     0.06  -0.12
# Market_commonality                 0.41   0.14   0.01  -0.08     0.03   0.12
# Size                               9.37   1.76   0.41   0.30    -0.16   0.18
# Year                            2003.51   5.19  -0.14   0.04     0.09  -0.06
#
#                                   ASA Absorbed_slack Unabsorbed_slack  \
#                     statistics
# RD                               0.06          -0.04            -0.18
# BSA                              0.14          -0.06            -0.16
# DURATION                        -0.18          -0.01             0.06
# GROWTH                           0.11          -0.19            -0.09
# ASA                              1.00          -0.01             0.10
# Absorbed_slack                  -0.01           1.00             0.01
# Unabsorbed_slack                 0.10           0.01             1.00
# Absorptive_capacity              0.13           0.00             0.34
# Market_commonality              -0.02          -0.02             0.06
# Size                             0.04          -0.10            -0.37
# Year                            -0.03           0.07            -0.09
#
#                                Absorptive_capacity Market_commonality   Size  \
#                     statistics
# RD                                           -0.07               0.01   0.41
# BSA                                          -0.46              -0.08   0.30
# DURATION                                      0.06               0.03  -0.16
# GROWTH                                       -0.12               0.12   0.18
# ASA                                           0.13              -0.02   0.04
# Absorbed_slack                                0.00              -0.02  -0.10
# Unabsorbed_slack                              0.34               0.06  -0.37
# Absorptive_capacity                           1.00               0.09  -0.29
# Market_commonality                            0.09               1.00   0.04
# Size                                         -0.29               0.04   1.00
# Year                                         -0.11              -0.24   0.25
#
#                                  Year
#                     statistics
# RD                              -0.14
# BSA                              0.04
# DURATION                         0.09
# GROWTH                          -0.06
# ASA                             -0.03
# Absorbed_slack                   0.07
# Unabsorbed_slack                -0.09
# Absorptive_capacity             -0.11
# Market_commonality              -0.24
# Size                             0.25
# Year                             1.00
#                                    mean    std       RD      BSA DURATION  \
#                     statistics
# RD                                 8.04   8.55     1.00     0.14    -0.20
#                     p-value         NaN    NaN  (1.000)  (0.000)  (0.000)
# BSA                               -0.10   0.21     0.14     1.00    -0.19
#                     p-value         NaN    NaN  (0.000)  (1.000)  (0.000)
# DURATION                           3.67   6.52    -0.20    -0.19     1.00
#                     p-value         NaN    NaN  (0.000)  (0.000)  (1.000)
# GROWTH                             0.15   0.16     0.06     0.05    -0.02
#                     p-value         NaN    NaN  (0.175)  (0.220)  (0.719)
# ASA                                0.10   0.33     0.06     0.14    -0.18
#                     p-value         NaN    NaN  (0.102)  (0.000)  (0.000)
# Absorbed_slack                     1.97  37.88    -0.04    -0.06    -0.01
#                     p-value         NaN    NaN  (0.322)  (0.094)  (0.760)
# Unabsorbed_slack                   1.39   1.99    -0.18    -0.16     0.06
#                     p-value         NaN    NaN  (0.000)  (0.000)  (0.132)
# Absorptive_capacity                0.23   0.72    -0.07    -0.46     0.06
#                     p-value         NaN    NaN  (0.046)  (0.000)  (0.055)
# Market_commonality                 0.41   0.14     0.01    -0.08     0.03
#                     p-value         NaN    NaN  (0.771)  (0.014)  (0.372)
# Size                               9.37   1.76     0.41     0.30    -0.16
#                     p-value         NaN    NaN  (0.000)  (0.000)  (0.000)
# Year                            2003.51   5.19    -0.14     0.04     0.09
#                     p-value         NaN    NaN  (0.000)  (0.211)  (0.003)
#
#                                  GROWTH      ASA Absorbed_slack  \
#                     statistics
# RD                                 0.06     0.06          -0.04
#                     p-value     (0.175)  (0.102)        (0.322)
# BSA                                0.05     0.14          -0.06
#                     p-value     (0.220)  (0.000)        (0.094)
# DURATION                          -0.02    -0.18          -0.01
#                     p-value     (0.719)  (0.000)        (0.760)
# GROWTH                             1.00     0.11          -0.19
#                     p-value     (1.000)  (0.010)        (0.000)
# ASA                                0.11     1.00          -0.01
#                     p-value     (0.010)  (1.000)        (0.722)
# Absorbed_slack                    -0.19    -0.01           1.00
#                     p-value     (0.000)  (0.722)        (1.000)
# Unabsorbed_slack                  -0.09     0.10           0.01
#                     p-value     (0.070)  (0.007)        (0.771)
# Absorptive_capacity               -0.12     0.13           0.00
#                     p-value     (0.004)  (0.000)        (0.952)
# Market_commonality                 0.12    -0.02          -0.02
#                     p-value     (0.005)  (0.560)        (0.662)
# Size                               0.18     0.04          -0.10
#                     p-value     (0.000)  (0.296)        (0.014)
# Year                              -0.06    -0.03           0.07
#                     p-value     (0.175)  (0.416)        (0.069)
#
#                                Unabsorbed_slack Absorptive_capacity  \
#                     statistics
# RD                                        -0.18               -0.07
#                     p-value             (0.000)             (0.046)
# BSA                                       -0.16               -0.46
#                     p-value             (0.000)             (0.000)
# DURATION                                   0.06                0.06
#                     p-value             (0.132)             (0.055)
# GROWTH                                    -0.09               -0.12
#                     p-value             (0.070)             (0.004)
# ASA                                        0.10                0.13
#                     p-value             (0.007)             (0.000)
# Absorbed_slack                             0.01                0.00
#                     p-value             (0.771)             (0.952)
# Unabsorbed_slack                           1.00                0.34
#                     p-value             (1.000)             (0.000)
# Absorptive_capacity                        0.34                1.00
#                     p-value             (0.000)             (1.000)
# Market_commonality                         0.06                0.09
#                     p-value             (0.092)             (0.011)
# Size                                      -0.37               -0.29
#                     p-value             (0.000)             (0.000)
# Year                                      -0.09               -0.11
#                     p-value             (0.015)             (0.001)
#
#                                Market_commonality     Size     Year
#                     statistics
# RD                                           0.01     0.41    -0.14
#                     p-value               (0.771)  (0.000)  (0.000)
# BSA                                         -0.08     0.30     0.04
#                     p-value               (0.014)  (0.000)  (0.211)
# DURATION                                     0.03    -0.16     0.09
#                     p-value               (0.372)  (0.000)  (0.003)
# GROWTH                                       0.12     0.18    -0.06
#                     p-value               (0.005)  (0.000)  (0.175)
# ASA                                         -0.02     0.04    -0.03
#                     p-value               (0.560)  (0.296)  (0.416)
# Absorbed_slack                              -0.02    -0.10     0.07
#                     p-value               (0.662)  (0.014)  (0.069)
# Unabsorbed_slack                             0.06    -0.37    -0.09
#                     p-value               (0.092)  (0.000)  (0.015)
# Absorptive_capacity                          0.09    -0.29    -0.11
#                     p-value               (0.011)  (0.000)  (0.001)
# Market_commonality                           1.00     0.04    -0.24
#                     p-value               (1.000)  (0.306)  (0.000)
# Size                                         0.04     1.00     0.25
#                     p-value               (0.306)  (1.000)  (0.000)
# Year                                        -0.24     0.25     1.00
#                     p-value               (0.000)  (0.000)  (1.000)

# %% [markdown]
# ## Regression - Mediation

# %%
mydata = df[['Id','RD','BSA','DURATION','GROWTH','ASA','Absorbed_slack','Unabsorbed_slack','Absorptive_capacity','Market_commonality','Size','Year']]
mydata = mydata.dropna()
mydata = (mydata - mydata.min()) / (mydata.max() - mydata.min()) 
mydata = mydata.sort_values(by=['Id','Year'], axis=0, ascending=True)
mediator_model = sm.OLS.from_formula('GROWTH~BSA', data=mydata)
outcome_model = sm.OLS.from_formula('RD~BSA+DURATION+GROWTH+ASA+Absorbed_slack+Unabsorbed_slack+Absorptive_capacity+Market_commonality+Size+C(Id)+C(Year)',data=mydata)   
mediator = mediator_model.fit(cov_type='HC1')
print(mediator.summary())
outcome = outcome_model.fit(cov_type='hac-panel', cov_kwds={'maxlags':1, 'groups':mydata['Id']})
print(outcome.summary())
effects = Mediation(outcome_model,mediator_model,"BSA","GROWTH").fit(n_rep=500)
effects.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 GROWTH   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.869
# Date:                Thu, 11 Mar 2021   Prob (F-statistic):             0.0911
# Time:                        11:04:29   Log-Likelihood:                 9.2531
# No. Observations:                 374   AIC:                            -14.51
# Df Residuals:                     372   BIC:                            -6.658
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0334      0.109      0.307      0.759      -0.180       0.246
# BSA            0.1942      0.115      1.694      0.090      -0.031       0.419
# ==============================================================================
# Omnibus:                       85.448   Durbin-Watson:                   0.374
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              140.780
# Skew:                           1.407   Prob(JB):                     2.69e-31
# Kurtosis:                       4.057   Cond. No.                         22.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     RD   R-squared:                       0.808
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                     19.39
# Date:                Thu, 11 Mar 2021   Prob (F-statistic):           8.87e-18
# Time:                        11:04:29   Log-Likelihood:                 420.22
# No. Observations:                 374   AIC:                            -704.4
# Df Residuals:                     306   BIC:                            -437.6
# Df Model:                          67
# Covariance Type:            hac-panel
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          -0.1892      0.141     -1.341      0.180      -0.466       0.087
# C(Id)[T.0.01818181818181818]        0.1914      0.041      4.658      0.000       0.111       0.272
# C(Id)[T.0.03636363636363636]        0.2089      0.086      2.423      0.015       0.040       0.378
# C(Id)[T.0.05454545454545454]       -0.0085      0.031     -0.279      0.780      -0.068       0.051
# C(Id)[T.0.09090909090909091]        0.1095      0.058      1.885      0.059      -0.004       0.223
# C(Id)[T.0.10909090909090909]        0.2398      0.051      4.745      0.000       0.141       0.339
# C(Id)[T.0.14545454545454545]        0.2537      0.033      7.681      0.000       0.189       0.318
# C(Id)[T.0.16363636363636364]        0.0990      0.072      1.383      0.167      -0.041       0.239
# C(Id)[T.0.18181818181818182]        0.0988      0.035      2.816      0.005       0.030       0.168
# C(Id)[T.0.2]                        0.2747      0.051      5.352      0.000       0.174       0.375
# C(Id)[T.0.23636363636363636]        0.0647      0.077      0.836      0.403      -0.087       0.216
# C(Id)[T.0.2545454545454545]         0.3640      0.043      8.427      0.000       0.279       0.449
# C(Id)[T.0.2727272727272727]         0.1889      0.071      2.672      0.008       0.050       0.328
# C(Id)[T.0.2909090909090909]         0.1709      0.071      2.397      0.017       0.031       0.311
# C(Id)[T.0.3090909090909091]         0.1350      0.068      1.998      0.046       0.003       0.267
# C(Id)[T.0.4]                        0.2831      0.092      3.074      0.002       0.103       0.464
# C(Id)[T.0.41818181818181815]        0.1291      0.091      1.421      0.155      -0.049       0.307
# C(Id)[T.0.43636363636363634]        0.2287      0.037      6.136      0.000       0.156       0.302
# C(Id)[T.0.45454545454545453]        0.1913      0.057      3.340      0.001       0.079       0.304
# C(Id)[T.0.4909090909090909]         0.1854      0.059      3.139      0.002       0.070       0.301
# C(Id)[T.0.509090909090909]          0.1801      0.057      3.145      0.002       0.068       0.292
# C(Id)[T.0.5272727272727272]         0.1568      0.072      2.186      0.029       0.016       0.297
# C(Id)[T.0.5454545454545454]         0.3798      0.056      6.751      0.000       0.270       0.490
# C(Id)[T.0.5636363636363636]         0.0247      0.064      0.385      0.701      -0.101       0.150
# C(Id)[T.0.5818181818181818]         0.3609      0.052      7.000      0.000       0.260       0.462
# C(Id)[T.0.6363636363636364]         0.1926      0.089      2.170      0.030       0.019       0.366
# C(Id)[T.0.6545454545454545]         0.3754      0.074      5.098      0.000       0.231       0.520
# C(Id)[T.0.6727272727272727]         0.0820      0.058      1.405      0.160      -0.032       0.196
# C(Id)[T.0.6909090909090909]         0.3454      0.067      5.176      0.000       0.215       0.476
# C(Id)[T.0.7090909090909091]         0.1182      0.040      2.920      0.003       0.039       0.198
# C(Id)[T.0.7454545454545455]         0.5820      0.068      8.588      0.000       0.449       0.715
# C(Id)[T.0.7636363636363637]         0.1812      0.038      4.829      0.000       0.108       0.255
# C(Id)[T.0.7818181818181819]        -0.0207      0.039     -0.530      0.596      -0.097       0.056
# C(Id)[T.0.8]                        0.4932      0.045     11.058      0.000       0.406       0.581
# C(Id)[T.0.8181818181818182]         0.2494      0.052      4.812      0.000       0.148       0.351
# C(Id)[T.0.8545454545454545]         0.0306      0.068      0.449      0.653      -0.103       0.164
# C(Id)[T.0.8727272727272727]         0.1937      0.074      2.627      0.009       0.049       0.338
# C(Id)[T.0.8909090909090909]         0.1445      0.087      1.655      0.098      -0.027       0.316
# C(Id)[T.0.9090909090909091]         0.0906      0.034      2.643      0.008       0.023       0.158
# C(Id)[T.0.9454545454545454]         0.2180      0.039      5.559      0.000       0.141       0.295
# C(Id)[T.0.9636363636363636]         0.1629      0.061      2.667      0.008       0.043       0.283
# C(Id)[T.1.0]                        0.1385      0.032      4.371      0.000       0.076       0.201
# C(Year)[T.0.058823529411764705]     0.0908      0.047      1.951      0.051      -0.000       0.182
# C(Year)[T.0.11764705882352941]      0.1579      0.046      3.443      0.001       0.068       0.248
# C(Year)[T.0.17647058823529413]      0.1312      0.050      2.616      0.009       0.033       0.230
# C(Year)[T.0.23529411764705882]      0.1165      0.045      2.579      0.010       0.028       0.205
# C(Year)[T.0.29411764705882354]      0.1026      0.043      2.399      0.016       0.019       0.186
# C(Year)[T.0.35294117647058826]      0.1068      0.041      2.634      0.008       0.027       0.186
# C(Year)[T.0.4117647058823529]       0.0628      0.036      1.733      0.083      -0.008       0.134
# C(Year)[T.0.47058823529411764]      0.0670      0.038      1.772      0.076      -0.007       0.141
# C(Year)[T.0.5294117647058824]       0.0456      0.037      1.224      0.221      -0.027       0.119
# C(Year)[T.0.5882352941176471]       0.0638      0.039      1.652      0.099      -0.012       0.140
# C(Year)[T.0.6470588235294118]       0.0450      0.037      1.202      0.229      -0.028       0.118
# C(Year)[T.0.7058823529411765]       0.0398      0.037      1.086      0.278      -0.032       0.112
# C(Year)[T.0.7647058823529411]      -0.0161      0.038     -0.429      0.668      -0.090       0.058
# C(Year)[T.0.8235294117647058]      -0.0114      0.039     -0.294      0.769      -0.087       0.065
# C(Year)[T.0.8823529411764706]      -0.0512      0.039     -1.303      0.193      -0.128       0.026
# C(Year)[T.0.9411764705882353]      -0.0315      0.040     -0.780      0.436      -0.111       0.048
# C(Year)[T.1.0]                     -0.0495      0.043     -1.153      0.249      -0.134       0.035
# BSA                                 0.0235      0.053      0.446      0.656      -0.080       0.127
# DURATION                           -0.1720      0.103     -1.662      0.096      -0.375       0.031
# GROWTH                              0.0728      0.061      1.187      0.235      -0.047       0.193
# ASA                                 0.0933      0.067      1.400      0.162      -0.037       0.224
# Absorbed_slack                      0.1268      0.091      1.395      0.163      -0.051       0.305
# Unabsorbed_slack                   -0.0668      0.052     -1.295      0.195      -0.168       0.034
# Absorptive_capacity                -0.0397      0.045     -0.891      0.373      -0.127       0.048
# Market_commonality                  0.0329      0.042      0.788      0.430      -0.049       0.115
# Size                                0.0872      0.145      0.602      0.547      -0.197       0.371
# ==============================================================================
# Omnibus:                       48.527   Durbin-Watson:                   1.382
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              117.601
# Skew:                           0.648   Prob(JB):                     2.91e-26
# Kurtosis:                       5.422   Cond. No.                         124.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (HAC-Panel)
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)            0.013719       -0.022411        0.062770    0.468
# ACME (treated)            0.013719       -0.022411        0.062770    0.468
# ADE (control)             0.025921       -0.137469        0.179849    0.724
# ADE (treated)             0.025921       -0.137469        0.179849    0.724
# Total effect              0.039641       -0.122476        0.193913    0.624
# Prop. mediated (control)  0.064899       -2.500307        2.280634    0.740
# Prop. mediated (treated)  0.064899       -2.500307        2.280634    0.740
# ACME (average)            0.013719       -0.022411        0.062770    0.468
# ADE (average)             0.025921       -0.137469        0.179849    0.724
# Prop. mediated (average)  0.064899       -2.500307        2.280634    0.740
